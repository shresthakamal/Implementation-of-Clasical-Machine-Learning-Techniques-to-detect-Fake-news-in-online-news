# %%
#TOKENIZATION                Done
#PUNCTUATION COUNT           Done
#STOP WORDS REMOVAL          Done
#STEMMING
#LEMMAZITATION

import pandas as pd
import numpy as np
import nltk
import nltk.data
from numpy import dot
from nltk.tokenize import word_tokenize, sent_tokenize
from string import punctuation
from collections import Counter
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

nltk.download('punkt')
nltk.download('stopwords')
#title and description are the attributes taken for this code file
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Justin
# [nltk_data]     Karki\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Justin
# [nltk_data]     Karki\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
data=pd.read_csv('C:/Users/Justin Karki/Desktop/Real.csv')
data
# Out:
#        source/id  source/name                            author  \
# 0       abc-news     ABC News              The Associated Press
# 1       abc-news     ABC News              The Associated Press
# 2       abc-news     ABC News              The Associated Press
# 3       abc-news     ABC News                       Karma Allen
# 4       abc-news     ABC News              The Associated Press
# 5       abc-news     ABC News              The Associated Press
# 6       abc-news     ABC News              The Associated Press
# 7       abc-news     ABC News                       Karma Allen
# 8       abc-news     ABC News              The Associated Press
# 9       abc-news     ABC News              The Associated Press
# 10      abc-news     ABC News                       Karma Allen
# 11      abc-news     ABC News              The Associated Press
# 12      abc-news     ABC News              The Associated Press
# 13      abc-news     ABC News                       Karma Allen
# 14      abc-news     ABC News              The Associated Press
# 15      abc-news     ABC News              The Associated Press
# 16      abc-news     ABC News              The Associated Press
# 17      abc-news     ABC News                       Karma Allen
# 18      abc-news     ABC News              The Associated Press
# 19      abc-news     ABC News              The Associated Press
# 20      bbc-news     BBC News                          BBC News
# 21      bbc-news     BBC News  https://www.facebook.com/bbcnews
# 22      bbc-news     BBC News  https://www.facebook.com/bbcnews
# 23      bbc-news     BBC News                               NaN
# 24      bbc-news     BBC News  https://www.facebook.com/bbcnews
# 25      bbc-news     BBC News  https://www.facebook.com/bbcnews
# 26      bbc-news     BBC News                               NaN
# 27      bbc-news     BBC News  https://www.facebook.com/bbcnews
# 28      bbc-news     BBC News                               NaN
# 29      bbc-news     BBC News  https://www.facebook.com/bbcnews
# ..           ...          ...                               ...
# 713      polygon      Polygon                 Michael McWhertor
# 714      polygon      Polygon                         Karen Han
# 715      polygon      Polygon                         Karen Han
# 716      polygon      Polygon                         Dave Tach
# 717      polygon      Polygon                      Ryan Gilliam
# 718      polygon      Polygon                     Austen Goslin
# 719      polygon      Polygon                 Michael McWhertor
# 720      polygon      Polygon                     Jenna Stoeber
# 721      polygon      Polygon                      Ryan Gilliam
# 722      polygon      Polygon                 Petrana Radulovic
# 723  news-com-au  News.com.au                       Rohan Smith
# 724  news-com-au  News.com.au                        Ben Graham
# 725  news-com-au  News.com.au                               NaN
# 726  news-com-au  News.com.au                               NaN
# 727  news-com-au  News.com.au                        Sam Clench
# 728  news-com-au  News.com.au                      Hannah Paine
# 729  news-com-au  News.com.au                     New York Post
# 730  news-com-au  News.com.au                     Rhian Deutrom
# 731  news-com-au  News.com.au                      Jamie Seidel
# 732  news-com-au  News.com.au                                Ap
# 733  news-com-au  News.com.au                       Luke Costin
# 734  news-com-au  News.com.au                    Shannon Molloy
# 735  news-com-au  News.com.au                       Ally Foster
# 736  news-com-au  News.com.au                               NaN
# 737  news-com-au  News.com.au                    Marnie O’neill
# 738  news-com-au  News.com.au                     Staff Writers
# 739  news-com-au  News.com.au                        Bronte Coy
# 740  news-com-au  News.com.au                      Kathy Mccabe
# 741  news-com-au  News.com.au                      Staff Writer
# 742  news-com-au  News.com.au                      Tim Birkhead
#
#                                                  title  \
# 0    Trump says top White House economist Kevin Has...
# 1    Prosperity, repression mark China 30 years aft...
# 2    Chicago police investigating 'unauthorized' vi...
# 3    10 dead, at least 35 wounded in Chicago since ...
# 4    Trump: 'Not happy' about 'messed up' Israeli p...
# 5    Top North Korean official reappears days after...
# 6    Illinois House skirts salary-freeze, set for p...
# 7    Boeing notifies FAA about improperly made part...
# 8    Legal document alleges EU migrant 'crimes agai...
# 9    China blames US for trade dispute, but doesn't...
# 10           Toddler falls into coma after a tick bite
# 11   Nobody hurt in California gas blast that rattl...
# 12   Boeing warns of potential wing problems in som...
# 13   Dwyane Wade surprises Parkland high school gra...
# 14   Canada suspending operations at embassy in Ven...
# 15   Texas governor signs state ban on red-light tr...
# 16   YouTube, other services down due to eastern US...
# 17   Child escapes 'serious injury' after attempted...
# 18   Dwyane Wade surprises graduates at Stoneman Do...
# 19   Car bomb in rebel-held northern Syria kills 13...
# 20            Clashes break out at Jerusalem holy site
# 21   Kim Yong-chol: 'Purged' N Korean diplomat appe...
# 22   Singapore fighter jets escort Scoot plane afte...
# 23                                2019/06/03 03:00 GMT
# 24    Sephora to shut US stores for diversity training
# 25        The Asian women who defied the driving taboo
# 26                                2019/06/03 02:00 GMT
# 27   Love Island: How will the fifth series be diff...
# 28                                2019/06/03 01:00 GMT
# 29         PM to challenge Trump's approach on climate
# ..                                                 ...
# 713  Spawn, Nightwolf, and Sindel confirmed for Mor...
# 714  The 20 best comedies streaming on Netflix righ...
# 715  Ali Wong, Randall Park, and even Keanu Reeves ...
# 716          Deadwood: The Movie is an improbable gift
# 717  Destiny 2 players can choose their own loot in...
# 718  Friday Fortnite is back, here’s who is competi...
# 719  Classic D&D RPGs Baldur’s Gate, Planescape: To...
# 720  We asked a cyber security expert to rate hacki...
# 721      Dauntless is proof more games need cross-save
# 722  Studio Ghibli theme park officially coming to ...
# 723  iTunes is over: Apple shutting down music, mov...
# 724  UK weather: Sun-starved Poms go bonkers in hea...
# 725  MAFS stars charging fans $20 for personalised ...
# 726  India weather: Temperature passes 50C Celsius ...
# 727  Game of Thrones: Brienne and Jaime scene from ...
# 728  The Voice Australia 2019: Jack Vidgen makes in...
# 729  Alligator invades home and leaves trail of des...
# 730  Apple announces it will shut down iTunes after...
# 731  Dark matter discovery: star stream ‘hole’ may ...
# 732  President Trump labels Meghan, Duchess of Suss...
# 733      NASA rocket launch: Arnhem Land chosen as hub
# 734  T-cell Lymphoblastic Leukaemia: Side effect fr...
# 735  Weather Qld, NSW, Vic: Coldest morning in Dalb...
# 736  Governments continue to cut nature reserves pr...
# 737  Disney, Netflix threaten to stop movie product...
# 738  Big Little Lies series two: Meryl Streep discu...
# 739  Harry Potter: Four new ebooks to be published ...
# 740  U2 to return to Australia with The Joshua Tree...
# 741  James Packer sells half his stake in Crown to ...
# 742  Climate change: Photo of seabirds starved to d...
#
#                                            description  \
# 0    Get breaking national and world news, broadcas...
# 1    Thirty years since the Tiananmen Square protes...
# 2    Chicago police are investigating after video w...
# 3    The Chicago Police Department attributed the s...
# 4    Get breaking national and world news, broadcas...
# 5    A senior North Korean official who had been re...
# 6    Get breaking national and world news, broadcas...
# 7    Boeing told officials with the Federal Aviatio...
# 8    Human rights lawyers are accusing the European...
# 9    Get breaking national and world news, broadcas...
# 10   Kayla Oblisk said her 2-year-old son, Jackson,...
# 11   Authorities say nobody was hurt when an explos...
# 12   Boeing is telling some airlines flying its 737...
# 13   Retired Miami Heat star Dwyane Wade surprised ...
# 14   Get breaking national and world news, broadcas...
# 15   Get breaking national and world news, broadcas...
# 16   Google is saying users of YouTube and other se...
# 17   The close call happened at Enchantment Park in...
# 18   Get breaking national and world news, broadcas...
# 19   Syrian opposition activists are reporting that...
# 20   Israeli police and Palestinian worshippers cla...
# 21   Kim Yong-chol was reported to be in a labour c...
# 22   Police are speaking to a 13-year-old passenger...
# 23   The latest five minute news bulletin from BBC ...
# 24   The "inclusion workshops" come after singer SZ...
# 25   They faced criticism and discouragement, but w...
# 26   The latest five minute news bulletin from BBC ...
# 27   ITV2 has made a few alterations to its most su...
# 28   The latest five minute news bulletin from BBC ...
# 29   Theresa May will raise the issue of climate ch...
# ..                                                 ...
# 713  MK11’s first Kombat Pack trailer shows off Sha...
# 714  If you’re looking for a laugh, the options on ...
# 715  Randall Park and Ali Wong star in a sweet roma...
# 716  David Milch resurrected his Western without mi...
# 717  Destiny 2 is all about the grind, and Bungie i...
# 718  Ninja and Nickmercs are just two of the massiv...
# 719  Classic BioWare and Black Isles Studios Dungeo...
# 720  From Spider-man to Bioshock to Assassin’s Cree...
# 721  In the new monster hunting game Dauntless, you...
# 722  Hayao Miyazaki’s legendary Studio Ghibli will ...
# 723  iTunes is over: Apple shutting down music, mov...
# 724  Sun-loving Brits flocked to beaches and parks ...
# 725  Some of this year’s Married At First Sight con...
# 726  India weather: Temperature passes 50C Celsius ...
# 727  Game of Thrones: Brienne and Jaime scene from ...
# 728  Former Australia’s Got Talent winner Jack Vidg...
# 729  An alligator measuring nearly 3.5 metres broke...
# 730  The iTunes platform was a vital part of Apple’...
# 731  We have a bullet hole. But there’s no smoking ...
# 732  US President Donald Trump has waded into the U...
# 733  NASA has signed a world-first deal with a priv...
# 734  Darrin Batchelor never imagined his four-year-...
# 735  As Aussies continue to shiver though the sudde...
# 736  Australian governments have slashed the legal ...
# 737  Disney has joined a growing list of major film...
# 738  Meryl Streep spoke out against the term ‘toxic...
# 739  Harry Potter: Four new ebooks to be published ...
# 740  U2 have finally confirmed their return to Aust...
# 741  James Packer has sold almost half of his stake...
# 742  Changes in seabird numbers are probably the be...
#
#                                                    url  \
# 0    https://abcnews.go.com/Politics/wireStory/trum...
# 1    https://abcnews.go.com/International/wireStory...
# 2    https://abcnews.go.com/US/wireStory/chicago-po...
# 3    https://abcnews.go.com/US/violent-chicago-week...
# 4    https://abcnews.go.com/Politics/wireStory/trum...
# 5    https://abcnews.go.com/International/wireStory...
# 6    https://abcnews.go.com/Politics/wireStory/illi...
# 7    https://abcnews.go.com/US/boeing-notifies-faa-...
# 8    https://abcnews.go.com/International/wireStory...
# 9    https://abcnews.go.com/Business/wireStory/chin...
# 10   https://abcnews.go.com/US/kentucky-toddler-fal...
# 11   https://abcnews.go.com/US/wireStory/hurt-calif...
# 12   https://abcnews.go.com/Lifestyle/wireStory/boe...
# 13   https://abcnews.go.com/US/dwyane-wade-surprise...
# 14   https://abcnews.go.com/International/wireStory...
# 15   https://abcnews.go.com/Lifestyle/wireStory/tex...
# 16   https://abcnews.go.com/US/wireStory/youtube-se...
# 17   https://abcnews.go.com/US/washington-child-esc...
# 18   https://abcnews.go.com/Sports/wireStory/dwyane...
# 19   https://abcnews.go.com/International/wireStory...
# 20   https://www.bbc.co.uk/news/av/world-middle-eas...
# 21      https://www.bbc.co.uk/news/world-asia-48493702
# 22      https://www.bbc.co.uk/news/world-asia-48493832
# 23    https://www.bbc.co.uk/programmes/w172wy0bkwtzkbx
# 24        https://www.bbc.co.uk/news/business-48493444
# 25   https://www.bbc.co.uk/news/uk-england-birmingh...
# 26    https://www.bbc.co.uk/programmes/w172wy0bkwtzfls
# 27   https://www.bbc.co.uk/news/entertainment-arts-...
# 28    https://www.bbc.co.uk/programmes/w172wy0bkwtz9vn
# 29   https://www.bbc.co.uk/news/science-environment...
# ..                                                 ...
# 713  https://www.polygon.com/2019/5/31/18648034/mor...
# 714  https://www.polygon.com/2019/5/31/18644138/bes...
# 715  https://www.polygon.com/2019/5/31/18647627/alw...
# 716  https://www.polygon.com/2019/5/31/18632931/dea...
# 717  https://www.polygon.com/2019/5/31/18647704/des...
# 718  https://www.polygon.com/fortnite/2019/5/31/186...
# 719  https://www.polygon.com/2019/5/31/18647633/bal...
# 720  https://www.polygon.com/videos/2019/5/31/18643...
# 721  https://www.polygon.com/2019/5/31/18646184/dau...
# 722  https://www.polygon.com/2019/5/31/18647575/stu...
# 723  https://www.news.com.au/technology/gadgets/mob...
# 724  https://www.news.com.au/technology/environment...
# 725  https://www.news.com.au/entertainment/tv/reali...
# 726  https://www.news.com.au/technology/environment...
# 727  https://www.news.com.au/entertainment/tv/game-...
# 728  https://www.news.com.au/entertainment/tv/reali...
# 729  https://www.news.com.au/technology/science/ani...
# 730  https://www.news.com.au/technology/gadgets/mob...
# 731  https://www.news.com.au/technology/science/spa...
# 732  https://www.news.com.au/entertainment/celebrit...
# 733  https://www.news.com.au/technology/science/spa...
# 734  https://www.news.com.au/technology/science/hum...
# 735  https://www.news.com.au/technology/environment...
# 736  https://www.news.com.au/technology/environment...
# 737  https://www.news.com.au/entertainment/movies/d...
# 738  https://www.news.com.au/entertainment/tv/big-l...
# 739  https://www.news.com.au/entertainment/books-ma...
# 740  https://www.news.com.au/entertainment/music/u2...
# 741  https://www.news.com.au/finance/business/other...
# 742  https://www.news.com.au/technology/science/ani...
#
#                                             urlToImage           publishedAt  \
# 0                                                  NaN  2019-06-03T03:20:13Z
# 1    https://s.abcnews.com/images/International/Wir...  2019-06-03T03:11:01Z
# 2                                                  NaN  2019-06-03T02:58:07Z
# 3    https://s.abcnews.com/images/US/chicago-police...  2019-06-03T02:12:48Z
# 4    https://s.abcnews.com/images/Politics/WireAP_e...  2019-06-03T01:56:10Z
# 5                                                  NaN  2019-06-03T01:30:58Z
# 6    https://s.abcnews.com/images/Politics/WireAP_1...  2019-06-03T00:46:44Z
# 7    https://s.abcnews.com/images/US/boeing-737-max...  2019-06-03T00:08:35Z
# 8    https://s.abcnews.com/images/International/Wir...  2019-06-03T00:04:43Z
# 9    https://s.abcnews.com/images/International/Wir...  2019-06-02T23:48:59Z
# 10   https://s.abcnews.com/images/US/tick-1-ht-er-1...  2019-06-02T22:57:36Z
# 11                                                 NaN  2019-06-02T22:55:19Z
# 12                                                 NaN  2019-06-02T22:48:32Z
# 13   https://s.abcnews.com/images/US/Dwyane-Wade-gt...  2019-06-02T22:01:43Z
# 14                                                 NaN  2019-06-02T21:46:28Z
# 15   https://s.abcnews.com/images/Lifestyle/WireAP_...  2019-06-02T21:30:17Z
# 16                                                 NaN  2019-06-02T21:30:13Z
# 17   https://s.abcnews.com/images/US/police-tape-er...  2019-06-02T21:10:13Z
# 18   https://s.abcnews.com/images/Sports/WireAP_e5b...  2019-06-02T20:14:02Z
# 19                                                 NaN  2019-06-02T20:01:27Z
# 20   https://ichef.bbci.co.uk/news/1024/branded_new...  2019-06-03T03:57:00Z
# 21   https://ichef.bbci.co.uk/news/1024/branded_new...  2019-06-03T03:41:18Z
# 22   https://ichef.bbci.co.uk/news/1024/branded_new...  2019-06-03T03:29:59Z
# 23   https://ichef.bbci.co.uk/images/ic/1200x675/p0...  2019-06-03T03:06:00Z
# 24   https://ichef.bbci.co.uk/news/1024/branded_new...  2019-06-03T02:45:06Z
# 25   https://ichef.bbci.co.uk/news/1024/branded_new...  2019-06-03T02:29:22Z
# 26   https://ichef.bbci.co.uk/images/ic/1200x675/p0...  2019-06-03T02:06:00Z
# 27   https://ichef.bbci.co.uk/news/1024/branded_new...  2019-06-03T01:20:36Z
# 28   https://ichef.bbci.co.uk/images/ic/1200x675/p0...  2019-06-03T01:06:00Z
# 29   https://ichef.bbci.co.uk/news/1024/branded_new...  2019-06-03T00:52:36Z
# ..                                                 ...                   ...
# 713  https://cdn.vox-cdn.com/thumbor/eAKldPpEI5oIk4...  2019-06-01T00:48:30Z
# 714  https://cdn.vox-cdn.com/thumbor/mCgHYCpQuDihq2...  2019-06-01T00:00:00Z
# 715  https://cdn.vox-cdn.com/thumbor/Z_tcgtjYkgFuwi...  2019-05-31T23:43:40Z
# 716  https://cdn.vox-cdn.com/thumbor/LO-Fv4sbzdvX7y...  2019-05-31T21:30:00Z
# 717  https://cdn.vox-cdn.com/thumbor/1jRrCuwYf2kF_4...  2019-05-31T20:30:00Z
# 718  https://cdn.vox-cdn.com/thumbor/iZp5pvvXUXyE7-...  2019-05-31T19:54:10Z
# 719  https://cdn.vox-cdn.com/thumbor/jQBK3E4xBU8JzX...  2019-05-31T19:14:54Z
# 720  https://cdn.vox-cdn.com/thumbor/tstQf7MYLpSJHX...  2019-05-31T19:00:00Z
# 721  https://cdn.vox-cdn.com/thumbor/w3enBT8in86Za4...  2019-05-31T18:45:00Z
# 722  https://cdn.vox-cdn.com/thumbor/RuwrNlM0q7k9Wm...  2019-05-31T18:21:50Z
# 723  https://cdn.newsapi.com.au/image/v1/d761a558ea...  2019-06-03T02:02:24Z
# 724  https://cdn.newsapi.com.au/image/v1/5fc9a3e828...  2019-06-03T00:21:49Z
# 725  https://cdn.newsapi.com.au/image/v1/bd0aab9c86...  2019-06-02T23:37:12Z
# 726                                                NaN  2019-06-02T20:42:33Z
# 727  https://cdn.newsapi.com.au/image/v1/6825a61a16...  2019-06-02T11:54:01Z
# 728  https://cdn.newsapi.com.au/image/v1/5de33b7c82...  2019-06-02T10:41:00Z
# 729  https://cdn.newsapi.com.au/image/v1/d76e20ee07...  2019-06-01T16:02:11Z
# 730  https://cdn.newsapi.com.au/image/v1/e915e199b6...  2019-06-01T07:48:21Z
# 731  https://cdn.newsapi.com.au/image/v1/527eacaf5d...  2019-06-01T00:45:02Z
# 732  https://cdn.newsapi.com.au/image/v1/f55f417d4f...  2019-06-01T00:04:21Z
# 733  https://cdn.newsapi.com.au/image/v1/e2512002e1...  2019-05-31T21:55:31Z
# 734  https://cdn.newsapi.com.au/image/v1/09f008ca00...  2019-05-31T12:23:24Z
# 735  https://cdn.newsapi.com.au/image/v1/33676c4a0f...  2019-05-31T03:55:33Z
# 736  https://cdn.newsapi.com.au/image/v1/745cf02661...  2019-05-31T03:24:25Z
# 737  https://cdn.newsapi.com.au/image/v1/c3567715d1...  2019-05-31T01:41:16Z
# 738  https://cdn.newsapi.com.au/image/v1/f4624fa87a...  2019-05-30T23:42:54Z
# 739  https://cdn.newsapi.com.au/image/v1/6454f26cec...  2019-05-30T21:04:15Z
# 740  https://cdn.newsapi.com.au/image/v1/c8ef9d56f2...  2019-05-30T20:26:42Z
# 741  https://cdn.newsapi.com.au/image/v1/dd272a6042...  2019-05-30T12:15:45Z
# 742  https://cdn.newsapi.com.au/image/v1/e8f447c387...  2019-05-30T10:11:53Z
#
#                                                content
# 0    President Donald Trump says the White House's ...
# 1    Thirty years since the Tiananmen Square protes...
# 2    Chicago police are investigating after video w...
# 3    At least 10 people were killed and 35 others w...
# 4    President Donald Trump says Israel has got to ...
# 5    A senior North Korean official who had been re...
# 6    Illinois lawmakers are in line for a $1,600-a-...
# 7    Boeing told officials with the Federal Aviatio...
# 8    More than 40,000 people have been intercepted ...
# 9    China fired back at the U.S. Sunday over the t...
# 10   A Kentucky mom says her son was left unconscio...
# 11   Authorities say nobody was hurt when an explos...
# 12   Boeing is telling some airlines flying its 737...
# 13   Retired Miami Heat star Dwyane Wade surprised ...
# 14   Canada is suspending operations at its embassy...
# 15   Texas Gov. Greg Abbott has signed a bill into ...
# 16   Google is saying users of YouTube and other se...
# 17   A young child escaped "serious injury" on Satu...
# 18   Retired NBA star Dwyane Wade was a surprise gu...
# 19   Syrian opposition activists are reporting that...
# 20                                                 NaN
# 21   Image copyrightKCNAImage caption\r\n Kim Yong-...
# 22   Image copyrightGetty ImagesImage caption\r\n T...
# 23   The latest five minute news bulletin from BBC ...
# 24   Image copyrightGetty Images\r\nBeauty chain Se...
# 25   Image copyrightAFPImage caption\r\n Suraksha A...
# 26   The latest five minute news bulletin from BBC ...
# 27   Image copyrightITVImage caption\r\n This year'...
# 28   The latest five minute news bulletin from BBC ...
# 29   Image copyrightJIM WEST/SCIENCE PHOTO LIBRARYI...
# ..                                                 ...
# 713  With hints of Ash from Evil Dead and the Termi...
# 714  From outright laugh riots to more bittersweet ...
# 715  Lets get the important details out of the way ...
# 716  Deadwood was a show that ended without an endi...
# 717  Earlier this week, Bungie revealed that player...
# 718  For the first time in almost a year, the Frida...
# 719  BioWare and Black Isle classics coming to PS4,...
# 720  The concept of hacking gets bandied about a lo...
# 721  When I logged off the PC version of Dauntlessl...
# 722  Hayao Miyazakis iconic Studio Ghibli, known fo...
# 723  It’s the question on the lips of many who adop...
# 724  Sun-loving Brits flocked to beaches and parks ...
# 725  Some of this years Married At First Sight cont...
# 726                                                NaN
# 727  It has been almost two weeks since the series ...
# 728  Former Australias Got Talent winner Jack Vidge...
# 729  An alligator measuring nearly 3.5 metres broke...
# 730  The iTunes platform was a vital part of Apples...
# 731  We have a bullet hole. But theres no smoking g...
# 732  US President Donald Trump has waded into the U...
# 733  NASA has signed a world-first deal with a priv...
# 734  Darrin Batchelor never imagined his four-year-...
# 735  As Aussies continue to shiver though the sudde...
# 736  Australian governments have slashed the legal ...
# 737  Disney has joined a growing list of major film...
# 738  Meryl Streep spoke out against the term toxic ...
# 739  Weve got some magical news for fans of the Har...
# 740  U2 have finally confirmed their return to Aust...
# 741  James Packer has sold almost half of his stake...
# 742  Changes in seabird numbers are probably the be...
#
# [743 rows x 9 columns]

# %%
data=data.loc[:,'title':'description']
#data=data.loc[:,['title','description']] #Alternative

# %%
title=data['title']               #Array of title of all rows
description=data['description']   #Array of description of all rows
x=len(title)
y=len(description)
print("Number of title and description is ",x," and ",y)
stop_words = set(stopwords.words("english")) #For removing stop words
# Out:
# Number of title and description is  743  and  743

# %%
#Punctuation count in each row of data.
#For Description

cnt_in_descr=0
#a=len(description)
check_descr=[]                    
i=0
for i in range(y):  
    #Loop from index 0 to last index
    check_descr=word_tokenize(description[i])     #Tokenization in row[i] in every step
    for w in check_descr:                         #If the Array of words(word tokens) of row[i]
        if w in punctuation:                      #contains punctuation, increase counter    
            cnt_in_descr+=1
    print("Punctuation in description row ", i+1, " is: ",cnt_in_descr)
    cnt_in_descr=0

    ### Left to Store in column "Description's Punctuations" like an attribute ###
    
#Alternative One line code using double for  

# descr_count=0
# words=sent_tokenize(description)
# for i in range(len(description)):
#     descr_count= Counter(descr_count for k in description for descr_count in k if descr_count in punctuation)
#print(description_counts)
# Out:
# Punctuation in description row  1  is:  4
# Punctuation in description row  2  is:  2
# Punctuation in description row  3  is:  0
# Punctuation in description row  4  is:  1
# Punctuation in description row  5  is:  4
# Punctuation in description row  6  is:  0
# Punctuation in description row  7  is:  4
# Punctuation in description row  8  is:  3
# Punctuation in description row  9  is:  0
# Punctuation in description row  10  is:  4
# Punctuation in description row  11  is:  3
# Punctuation in description row  12  is:  0
# Punctuation in description row  13  is:  2
# Punctuation in description row  14  is:  2
# Punctuation in description row  15  is:  4
# Punctuation in description row  16  is:  4
# Punctuation in description row  17  is:  1
# Punctuation in description row  18  is:  1
# Punctuation in description row  19  is:  4
# Punctuation in description row  20  is:  1
# Punctuation in description row  21  is:  2
# Punctuation in description row  22  is:  1
# Punctuation in description row  23  is:  1
# Punctuation in description row  24  is:  1
# Punctuation in description row  25  is:  1
# Punctuation in description row  26  is:  2
# Punctuation in description row  27  is:  1
# Punctuation in description row  28  is:  1
# Punctuation in description row  29  is:  1
# Punctuation in description row  30  is:  1
# Punctuation in description row  31  is:  1
# Punctuation in description row  32  is:  1
# Punctuation in description row  33  is:  1
# Punctuation in description row  34  is:  1
# Punctuation in description row  35  is:  1
# Punctuation in description row  36  is:  1
# Punctuation in description row  37  is:  5
# Punctuation in description row  38  is:  1
# Punctuation in description row  39  is:  3
# Punctuation in description row  40  is:  1
# Punctuation in description row  41  is:  2
# Punctuation in description row  42  is:  2
# Punctuation in description row  43  is:  3
# Punctuation in description row  44  is:  0
# Punctuation in description row  45  is:  1
# Punctuation in description row  46  is:  1
# Punctuation in description row  47  is:  1
# Punctuation in description row  48  is:  2
# Punctuation in description row  49  is:  1
# Punctuation in description row  50  is:  1
# Punctuation in description row  51  is:  1
# Punctuation in description row  52  is:  3
# Punctuation in description row  53  is:  7
# Punctuation in description row  54  is:  0
# Punctuation in description row  55  is:  0
# Punctuation in description row  56  is:  3
# Punctuation in description row  57  is:  2
# Punctuation in description row  58  is:  2
# Punctuation in description row  59  is:  1
# Punctuation in description row  60  is:  1
# Punctuation in description row  61  is:  3
# Punctuation in description row  62  is:  1
# Punctuation in description row  63  is:  4
# Punctuation in description row  64  is:  4
# Punctuation in description row  65  is:  3
# Punctuation in description row  66  is:  5
# Punctuation in description row  67  is:  1
# Punctuation in description row  68  is:  1
# Punctuation in description row  69  is:  1
# Punctuation in description row  70  is:  2
# Punctuation in description row  71  is:  2
# Punctuation in description row  72  is:  1
# Punctuation in description row  73  is:  1
# Punctuation in description row  74  is:  6
# Punctuation in description row  75  is:  2
# Punctuation in description row  76  is:  3
# Punctuation in description row  77  is:  1
# Punctuation in description row  78  is:  3
# Punctuation in description row  79  is:  2
# Punctuation in description row  80  is:  3
# Punctuation in description row  81  is:  2
# Punctuation in description row  82  is:  1
# Punctuation in description row  83  is:  3
# Punctuation in description row  84  is:  2
# Punctuation in description row  85  is:  3
# Punctuation in description row  86  is:  6
# Punctuation in description row  87  is:  2
# Punctuation in description row  88  is:  1
# Punctuation in description row  89  is:  1
# Punctuation in description row  90  is:  2
# Punctuation in description row  91  is:  2
# Punctuation in description row  92  is:  2
# Punctuation in description row  93  is:  1
# Punctuation in description row  94  is:  1
# Punctuation in description row  95  is:  4
# Punctuation in description row  96  is:  2
# Punctuation in description row  97  is:  7
# Punctuation in description row  98  is:  1
# Punctuation in description row  99  is:  5
# Punctuation in description row  100  is:  3
# Punctuation in description row  101  is:  2
# Punctuation in description row  102  is:  2
# Punctuation in description row  103  is:  3
# Punctuation in description row  104  is:  1
# Punctuation in description row  105  is:  3
# Punctuation in description row  106  is:  4
# Punctuation in description row  107  is:  4
# Punctuation in description row  108  is:  1
# Punctuation in description row  109  is:  1
# Punctuation in description row  110  is:  2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-9fe6e84a6053> in <module>()
#       8 for i in range(y):
#       9     #Loop from index 0 to last index
# ---> 10     check_descr=word_tokenize(description[i])     #Tokenization in row[i] in every step
#      11     for w in check_descr:                         #If the Array of words(word tokens) of row[i]
#      12         if w in punctuation:                      #contains punctuation, increase counter
#
# E:\Anaconda\lib\site-packages\nltk\tokenize\__init__.py in word_tokenize(text, language, preserve_line)
#     141     :type preserve_line: bool
#     142     """
# --> 143     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     144     return [
#     145         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#
# E:\Anaconda\lib\site-packages\nltk\tokenize\__init__.py in sent_tokenize(text, language)
#     103     """
#     104     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
# --> 105     return tokenizer.tokenize(text)
#     106
#     107
#
# E:\Anaconda\lib\site-packages\nltk\tokenize\punkt.py in tokenize(self, text, realign_boundaries)
#    1267         Given a text, returns a list of the sentences in that text.
#    1268         """
# -> 1269         return list(self.sentences_from_text(text, realign_boundaries))
#    1270
#    1271     def debug_decisions(self, text):
#
# E:\Anaconda\lib\site-packages\nltk\tokenize\punkt.py in sentences_from_text(self, text, realign_boundaries)
#    1321         follows the period.
#    1322         """
# -> 1323         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1324
#    1325     def _slices_from_text(self, text):
#
# E:\Anaconda\lib\site-packages\nltk\tokenize\punkt.py in <listcomp>(.0)
#    1321         follows the period.
#    1322         """
# -> 1323         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1324
#    1325     def _slices_from_text(self, text):
#
# E:\Anaconda\lib\site-packages\nltk\tokenize\punkt.py in span_tokenize(self, text, realign_boundaries)
#    1311         if realign_boundaries:
#    1312             slices = self._realign_boundaries(text, slices)
# -> 1313         for sl in slices:
#    1314             yield (sl.start, sl.stop)
#    1315
#
# E:\Anaconda\lib\site-packages\nltk\tokenize\punkt.py in _realign_boundaries(self, text, slices)
#    1352         """
#    1353         realign = 0
# -> 1354         for sl1, sl2 in _pair_iter(slices):
#    1355             sl1 = slice(sl1.start + realign, sl1.stop)
#    1356             if not sl2:
#
# E:\Anaconda\lib\site-packages\nltk\tokenize\punkt.py in _pair_iter(it)
#     315     """
#     316     it = iter(it)
# --> 317     prev = next(it)
#     318     for el in it:
#     319         yield (prev, el)
#
# E:\Anaconda\lib\site-packages\nltk\tokenize\punkt.py in _slices_from_text(self, text)
#    1325     def _slices_from_text(self, text):
#    1326         last_break = 0
# -> 1327         for match in self._lang_vars.period_context_re().finditer(text):
#    1328             context = match.group() + match.group('after_tok')
#    1329             if self.text_contains_sentbreak(context):
#
# TypeError: expected string or bytes-like object

# %%
#For title (above process)

i=0
cnt_in_title=0
for i in range(x):
    check_title=word_tokenize(title[i])
    for w in check_title:
        if w in punctuation:
            cnt_in_title+=1
    print("Punctuation in title row ", i+1, " is: ",cnt_in_title)
    cnt_in_title=0 
    
### Left to store in column "Title's Punctuation" like an attribute

# %%
#Removing stop words from title of the news
i=0
filtered_title=[]
for i in range(x):
    filtered_title=[]
    words_title = word_tokenize(title[i])
    for w in words_title:
        if w not in stop_words:
            filtered_title.append(w)
            
    words_title=filtered_title  
    print("Title for Row", i,"=", words_title)        #Stop Words removed. To print Uncomment 
    
    #print("The filtered title",i,"is",filtered_title)  
    #words_title[i]=filtered_title    #"list assignment index out of range" ERROR while trying to store in rows
    #print(words_title)        #Stop Words removed. Out of range 

#filtered_description= w for w in words if not w in stop_words    #Tokenzation
# Out:
# Title for Row 0 = ['Trump', 'says', 'top', 'White', 'House', 'economist', 'Kevin', 'Hassett', 'leaving']
# Title for Row 1 = ['Prosperity', ',', 'repression', 'mark', 'China', '30', 'years', 'Tiananmen']
# Title for Row 2 = ['Chicago', 'police', 'investigating', "'unauthorized", "'", 'video', 'release']
# Title for Row 3 = ['10', 'dead', ',', 'least', '35', 'wounded', 'Chicago', 'since', 'Friday']
# Title for Row 4 = ['Trump', ':', "'Not", 'happy', "'", "'messed", "'", 'Israeli', 'politics']
# Title for Row 5 = ['Top', 'North', 'Korean', 'official', 'reappears', 'days', 'purge', 'report']
# Title for Row 6 = ['Illinois', 'House', 'skirts', 'salary-freeze', ',', 'set', 'pay', 'increase']
# Title for Row 7 = ['Boeing', 'notifies', 'FAA', 'improperly', 'made', 'parts', '737', 'Max']
# Title for Row 8 = ['Legal', 'document', 'alleges', 'EU', 'migrant', "'crimes", 'humanity', "'"]
# Title for Row 9 = ['China', 'blames', 'US', 'trade', 'dispute', ',', "n't", 'escalate']
# Title for Row 10 = ['Toddler', 'falls', 'coma', 'tick', 'bite']
# Title for Row 11 = ['Nobody', 'hurt', 'California', 'gas', 'blast', 'rattled', 'buildings']
# Title for Row 12 = ['Boeing', 'warns', 'potential', 'wing', 'problems', '737', 'aircraft']
# Title for Row 13 = ['Dwyane', 'Wade', 'surprises', 'Parkland', 'high', 'school', 'graduates']
# Title for Row 14 = ['Canada', 'suspending', 'operations', 'embassy', 'Venezuela']
# Title for Row 15 = ['Texas', 'governor', 'signs', 'state', 'ban', 'red-light', 'traffic', 'cameras']
# Title for Row 16 = ['YouTube', ',', 'services', 'due', 'eastern', 'US', 'congestion']
# Title for Row 17 = ['Child', 'escapes', "'serious", 'injury', "'", 'attempted', 'cougar', 'attack', ':', 'Police']
# Title for Row 18 = ['Dwyane', 'Wade', 'surprises', 'graduates', 'Stoneman', 'Douglas']
# Title for Row 19 = ['Car', 'bomb', 'rebel-held', 'northern', 'Syria', 'kills', '13', 'people']
# Title for Row 20 = ['Clashes', 'break', 'Jerusalem', 'holy', 'site']
# Title for Row 21 = ['Kim', 'Yong-chol', ':', "'Purged", "'", 'N', 'Korean', 'diplomat', 'appears', 'Kim']
# Title for Row 22 = ['Singapore', 'fighter', 'jets', 'escort', 'Scoot', 'plane', 'bomb', 'hoax']
# Title for Row 23 = ['2019/06/03', '03:00', 'GMT']
# Title for Row 24 = ['Sephora', 'shut', 'US', 'stores', 'diversity', 'training']
# Title for Row 25 = ['The', 'Asian', 'women', 'defied', 'driving', 'taboo']
# Title for Row 26 = ['2019/06/03', '02:00', 'GMT']
# Title for Row 27 = ['Love', 'Island', ':', 'How', 'fifth', 'series', 'different', '?']
# Title for Row 28 = ['2019/06/03', '01:00', 'GMT']
# Title for Row 29 = ['PM', 'challenge', 'Trump', "'s", 'approach', 'climate']
# Title for Row 30 = ['CEO', 'Secrets', ':', "'", 'I', 'built', 'fashion', 'brand', 'selling', 'crisps', 'school', "'"]
# Title for Row 31 = ['The', 'wealthy', 'businessman', 'paid', '£35.20', 'tax']
# Title for Row 32 = ['Sir', 'Phillip', 'Green', "'s", 'Arcadia', 'facing', 'crucial', 'week']
# Title for Row 33 = ['2019/06/03', '00:00', 'GMT']
# Title for Row 34 = ['Peterborough', 'by-election', ':', 'The', "'mother", 'marginals', "'"]
# Title for Row 35 = ["'Before", 'knew', 'little', 'website', '350,000', 'users', "'"]
# Title for Row 36 = ['Pope', 'Francis', 'apologises', 'Roma', 'people', 'Catholic', 'discrimination']
# Title for Row 37 = ['Five', 'things', 'expect', 'week', 'ahead']
# Title for Row 38 = ['Cambridge', 'Scott', 'Polar', 'Inuit', "'muffin", 'top', "'", 'sculpture', 'fixed']
# Title for Row 39 = ['Newspaper', 'headlines', ':', 'Trump', 'visits', 'UK', 'Liverpool', "'paint", 'town', 'red', "'"]
# Title for Row 40 = ['2019', 'NBA', 'Finals', 'Odds', ':', 'Warriors', 'Open', '5.5-Point', 'Favorites', 'vs.', 'Raptors', 'Game', '3']
# Title for Row 41 = ['Warriors', "'", 'Klay', 'Thompson', 'Expects', 'Play', 'Game', '3', 'Despite', 'Hamstring', 'Injury']
# Title for Row 42 = ['Stephen', 'Curry', ':', 'Raptors', 'D', "'Disrespectful", "'", 'Leaving', 'Andre', 'Iguodala', 'Wide', 'Open']
# Title for Row 43 = ['Watch', 'Warriors', "'", 'Andre', 'Iguodala', 'Drain', 'Dagger', '3-Pointer', 'Ice', 'Game', '2', 'vs.', 'Raptors']
# Title for Row 44 = ['Warriors', "'", 'Klay', 'Thompson', 'Ruled', 'After', 'Suffering', 'Hamstring', 'Injury', 'Game', '2']
# Title for Row 45 = ['Stephen', 'Curry', "'s", '23', 'Lead', 'Warriors', 'Past', 'Kawhi', 'Leonard', ',', 'Raptors', 'Even', 'Series', '1']
# Title for Row 46 = ['Report', ':', 'Warriors', "'", 'Kevon', 'Looney', 'Suffers', 'Collarbone', 'Injury', 'NBA', 'Finals', 'Game', '2']
# Title for Row 47 = ['Michigan', 'RB', 'Chris', 'Evans', 'Suspended', 'Entire', '2019', 'Season', 'Due', 'Academic', 'Issue']
# Title for Row 48 = ['Video', ':', 'Drake', 'Rocks', "'Where", "'s", 'Kevin', '?', "'", 'Home', 'Alone', 'Hoodie', 'NBA', 'Finals', 'Game', '2']
# Title for Row 49 = ['Former', '5-Star', 'Recruit', 'Jahvon', 'Quinerly', 'Transfers', 'Villanova', 'Alabama']
# Title for Row 50 = ['Video', ':', 'Watch', 'Barack', 'Obama', 'Arrive', 'NBA', 'Finals', 'Game', '2', 'Raptors', "'", 'Masai', 'Ujiri']
# Title for Row 51 = ['Fan', 'Pays', 'Record-Breaking', '$', '101K', '2', 'Tickets', 'Warriors', 'vs.', 'Raptors', 'Game', '4']
# Title for Row 52 = ['Video', ':', 'Marlins', 'vs.', 'Padres', 'Game', 'Delayed', 'Bees', 'Swarm', 'Near', 'Dugout', 'Petco', 'Park']
# Title for Row 53 = ['Steve', 'Kerr', 'Wears', "'Vote", 'Our', 'Lives', "'", 'Shirt', 'After', 'Virginia', 'Beach', 'Shooting']
# Title for Row 54 = ['Jan', 'Vertonghen', 'Hopes', "'Everyone", 'Stays', "'", 'Following', 'Tottenham', "'s", 'UCL', 'Final', 'Defeat']
# Title for Row 55 = ['Illinois', 'State', 'Legislature', 'Passes', 'Bill', 'Legalizing', 'Sports', 'Gambling']
# Title for Row 56 = ['US', 'Women', "'s", 'Open', 'Golf', '2019', ':', 'Jeongeun', 'Lee6', 'Shoots', '6-Under', 'Win', '1st', 'Major']
# Title for Row 57 = ['Memorial', 'Tournament', '2019', ':', 'Patrick', 'Cantlay', 'Erases', '4-Stroke', 'Deficit', 'Earn', 'Win']
# Title for Row 58 = ['Video', ':', 'Batista', 'Reveals', 'He', 'Went', 'Broke', 'After', 'Leaving', 'WWE', ':', "'", 'I', 'Starved', '3', 'Years', "'"]
# Title for Row 59 = ['Dodgers', "'", 'Tony', 'Cingrani', 'Have', 'Shoulder', 'Surgery', ';', 'Not', 'Likely', 'Return', '2019']
# Title for Row 60 = ['Economists', "'", 'fears', '2020', 'recession', 'US', 'surge']
# Title for Row 61 = ['9', 'takeaways', 'Seth', 'Moulton', ',', 'Tim', 'Ryan', 'Eric', 'Swalwell', "'s", 'CNN', 'town', 'halls']
# Title for Row 62 = ['Best', 'places', 'visit', 'ultimate', 'Asia', 'experience']
# Title for Row 63 = ['Swalwell', ':', 'Move', 'impeach', 'people', 'Trump']
# Title for Row 64 = ['Tiananmen', 'Square', 'massacre', ':', 'How', 'Beijing', 'turned', 'people']
# Title for Row 65 = ['They', 'faced', 'tanks', 'Tiananmen', 'Square', '.', 'Now', 'want', 'children', 'forget']
# Title for Row 66 = ['Child', 'escapes', 'cougar', 'attack', 'Washington', 'minor', 'injuries']
# Title for Row 67 = ['Philippine', 'President', 'Duterte', 'says', "'used", 'gay', "'", "'cured", "'"]
# Title for Row 68 = ['Stelter', ':', 'Did', 'Mueller', "'s", 'TV', 'moment', 'matter', '?']
# Title for Row 69 = ['Washington', 'Post', ':', 'Pompeo', 'tries', 'manage', 'expectations', 'Middle', 'East', 'peace', 'plan']
# Title for Row 70 = ['Washington', 'Post', ':', 'Pompeo', 'tries', 'manage', 'expectations', 'Middle', 'East', 'peace', 'plan']
# Title for Row 71 = ['Anthony', 'Joshua', "'s", 'heavyweight', 'boxing', 'upset', 'blamed', 'Drake', 'curse']
# Title for Row 72 = ['Dow', 'futures', 'tumble', 'trade', 'war', 'escalates']
# Title for Row 73 = ["'Please", 'let', "'", ':', 'Former', 'Nxivm', 'member', 'testifies', 'held', 'room', '2', 'years']
# Title for Row 74 = ['Seth', 'Moulton', ':', "'If", 'country', "n't", 'racist', ',', 'Stacey', 'Abrams', 'would', 'Governor', "'"]
# Title for Row 75 = ['Seth', 'Moulton', ':', 'Nobody', 'fear', 'talking', 'mental', 'health', 'challenges', 'America']
# Title for Row 76 = ['Boeing', 'dice', 'que', 'algunos', 'de', 'sus', 'aviones', '737', 'Max', 'pueden', 'tener', 'partes', 'defectuosas']
# Title for Row 77 = ['Kamala', 'Harris', "'", 'husband', 'steps', 'onto', 'stage', 'defend', 'wife', 'spotlight']
# Title for Row 78 = ['India', 'massive', 'business', 'opportunity', 'America']
# Title for Row 79 = ['Dwyane', 'Wade', 'surprises', 'Marjory', 'Stoneman', 'Douglas', 'High', 'School', 'students', 'graduation', 'ceremony']
# Title for Row 80 = ['Warriors', 'ride', 'big', '3rd', 'quarter', 'even', 'NBA', 'Finals', 'series', 'Raptors']
# Title for Row 81 = ['Tips', 'teens', ':', 'Preparing', 'prom', 'touch-up', 'makeup']
# Title for Row 82 = ['A', 'helping', 'paw', ':', 'Delray', 'dog', 'supports', 'Alberta', 'paramedics']
# Title for Row 83 = ['Recycling', "n't", 'R', 'waste', 'reduction', ',', 'say', 'advocates']
# Title for Row 84 = ['Suspect', 'rams', 'vehicles', 'Walmart', 'parking', 'lot', 'avoid', 'arrest', ',', 'say', 'West', 'Kelowna', 'police']
# Title for Row 85 = ['Winnipeg', 'baking', 'phenom', 'wins', 'gold', 'national', 'competition']
# Title for Row 86 = ['Rare', 'white', 'bear', 'cub', 'spotted', 'Alberta', 'wildlife', 'photographers']
# Title for Row 87 = ['Firefighters', 'respond', 'apartment', 'fire', 'Vancouver', "'s", 'West', 'End']
# Title for Row 88 = ['UBC', 'hosts', 'Canada', "'s", 'largest', 'academic', 'conference', 'week']
# Title for Row 89 = ['The', 'art', 'dessert', ':', 'Japanese', 'wagashi', 'master', 'sculpts', 'intricate', 'pieces', 'bean', 'paste']
# Title for Row 90 = ["'Appalling", 'treatment', "'", ':', 'Couple', 'wheelchairs', 'left', 'alone', 'almost', '12', 'hours', 'Vancouver', 'airport']
# Title for Row 91 = ['Severe', 'thunderstorm', 'watch', 'Montreal', ',', 'tornado', 'warning', 'Saint-Jérôme', 'area']
# Title for Row 92 = ["'Gentle", 'densification', "'", ':', 'Unique', 'West', 'End', 'development', 'puts', '6', 'units', 'single', 'family', 'lot']
# Title for Row 93 = ['Body', 'found', 'scene', 'fire', 'near', 'Slave', 'Lake']
# Title for Row 94 = ['Jeongeun', 'Lee6', 'wins', 'U.S.', 'Women', "'s", 'Open']
# Title for Row 95 = ['Rockies', 'sweep', 'struggling', 'Blue', 'Jays', '8th', 'straight', 'win']
# Title for Row 96 = ['Hold', 'applause', 'Canada', "'s", 'consolation', 'win', 'Paris', '7s']
# Title for Row 97 = ["'We", 'took', 'cover', "'", ':', 'Orléans', 'reeling', 'tornado', 'tears', 'region']
# Title for Row 98 = ['Tornado', 'warning', 'still', 'place', 'Gatineau', 'area', ',', 'Prescott-Russell']
# Title for Row 99 = ['Tornado', 'warning', 'issued', 'Gatineau']
# Title for Row 100 = ['Beijing', 'vows', 'defend', "'islands", 'rocks', "'", 'South', 'China', 'Sea']
# Title for Row 101 = ['US', 'set', 'grant', 'tentative', 'approval', 'American', 'Airlines-Qantas', 'venture']
# Title for Row 102 = ['Sephora', 'shut', 'US', 'stores', 'day', 'conduct', 'diversity', 'training', 'racial', 'incident']
# Title for Row 103 = ['Trump', 'announces', 'departure', 'White', 'House', 'economic', 'advisor', 'Kevin', 'Hassett']
# Title for Row 104 = ['A', 'private', 'survey', 'shows', 'China', "'s", 'manufacturing', 'activity', 'May', 'steady', '50.2']
# Title for Row 105 = ['Oil', 'prices', 'extend', 'drop', 'trade', 'wars', 'stoke', 'global', 'economic', 'fears']
# Title for Row 106 = ['Google', 'political', 'allies', 'history', 'complaints', ',', 'antitrust', 'case', 'may', 'move', 'quickly']
# Title for Row 107 = ['North', 'Korea', "'s", 'former', 'top', 'nuclear', 'envoy', 'reportedly', 'seen', 'Kim', 'Jong', 'Un']
# Title for Row 108 = ['Asia', 'markets', 'set', 'decline', 'trade', 'fears', 'heat']
# Title for Row 109 = ['Market', 'bull', 'cuts', 'exposure', 'stocks', 'due', 'new', 'Mexico', 'tariff', 'threat']
# Title for Row 110 = ['Google', 'looking', 'service', 'outages', 'cloud', 'experiences', "'larger", 'network', 'issue', "'"]
# Title for Row 111 = ['Boeing', 'notifies', 'FAA', '737', 'Max', 'parts', 'may', "'susceptible", 'premature', 'failure', "'"]
# Title for Row 112 = ['Boeing', 'notifies', 'FAA', '737', 'Max', 'parts', 'may', "'susceptible", 'premature', 'failure', "'"]
# Title for Row 113 = ['Trump', 'lashes', 'Mexico', 'ahead', 'border', 'talks', ':', "'We", 'want', 'action', ',', 'talk', "'"]
# Title for Row 114 = ['Morgan', 'Stanley', 'sees', 'global', 'recession', "'in", 'three', 'quarters', "'", 'Trump', 'escalates', 'trade', 'war']
# Title for Row 115 = ['Here', "'s", 'Justice', 'Department', 'wants', 'go', 'Google']
# Title for Row 116 = ['Trump', 'encourages', 'UK', 'go', 'no-deal', 'Brexit', 'EU', "n't", 'agree', 'favorable', 'terms']
# Title for Row 117 = ['London', 'Mayor', 'Sadiq', 'Khan', 'compares', 'Trump', '20th', 'century', 'fascists', 'ahead', 'UK', 'visit']
# Title for Row 118 = ['Why', "'Rocketman", "'", 'winning', 'rave', 'reviews', 'wo', "n't", 'necessarily', 'boost', 'interest', 'Elton', 'John', "'s", 'music']
# Title for Row 119 = ['Warriors', 'star', 'Draymond', 'Green', 'wants', 'billionaire', 'age', '40—here', "'s", '3-step', 'plan']
# Title for Row 120 = ['Gatwick', 'Airport', 'evacuated', "'knifeman", 'seen', "'"]
# Title for Row 121 = ['Bella', 'Thorne', "'s", 'ex', 'Mod', 'Sun', 'tries', 'suggest', 'stepped', 'post-breakup', 'interview']
# Title for Row 122 = ['Terri', ',', 'Bindi', 'Robert', 'Irwin', 'strike', 'pose', 'Critics', 'Choice', 'Real', 'TV', 'Awards', 'LA']
# Title for Row 123 = ['Parents', 'share', 'hilarious', 'drawing', 'kids', 'done', 'years']
# Title for Row 124 = ['Woman', 'jumps', 'second-floor', 'window', 'New', 'York', 'apartment', "'adult", 'club', 'manager,59', ',', 'raped', "'"]
# Title for Row 125 = ['Leaked', 'video', 'shows', 'James', 'Holzhauer', "'s", '32-day', 'winning', 'streak', 'Jeopardy', '!', 'come', 'end']
# Title for Row 126 = ['Half-naked', 'hero', 'armed', 'nothing', 'didgeridoo', 'charges', 'burglar']
# Title for Row 127 = ['Deborah', 'Knight', 'forced', 'read', 'paper', 'script', 'autocue', 'fails', 'Nine', 'News']
# Title for Row 128 = ['Whistleblower', "'exposed", 'ATO', "'s", 'practices', "'", 'breaks', 'silence', 'faces', '161', 'years', 'jail']
# Title for Row 129 = ['House', 'Rules', "'", 'Shayn', 'Carly', 'reveal', 'plan', 'another', 'baby', 'win', 'show']
# Title for Row 130 = ['MAFS', 'star', 'Telv', 'Williams', ',', '34', ',', 'fined', 'punch-on']
# Title for Row 131 = ['Actor', 'Jason', 'Clarke', 'French', 'wife', 'Cécile', 'Breccia', 'share', 'laugh', 'farmer', "'s", 'market']
# Title for Row 132 = ['Matthew', 'Mitcham', 'ENGAGED', 'Luke', 'Rutherford', 'six', 'months', 'dating']
# Title for Row 133 = ['Video', ':', 'Deborah', 'Knight', 'forced', 'read', 'paper', 'script', 'technical', 'error']
# Title for Row 134 = ['Cast', 'revealed', 'Seven', "'s", 'new', 'series', 'The', 'Super', 'Switch']
# Title for Row 135 = ['Pregnant', 'bikini', 'model', 'slammed', 'taking', 'staged', 'photo', 'full', 'hair', 'makeup', 'labour']
# Title for Row 136 = ['Lala', 'Kent', 'attends', 'Critics', "'", 'Choice', 'Real', 'TV', 'Awards', 'nude', 'mini', 'sheer', 'black', 'overlay']
# Title for Row 137 = ['Martha', 'Kalifatidis', "'considering", 'making', 'SEX', 'TAPE', "'", 'like', 'Kim', 'Kardashian']
# Title for Row 138 = ['The', 'Voice', "'s", 'Kim', 'Sheehy', 'says', 'show', 'empowered', 'come', 'lesbian', '-', 'ahead', 'All', 'Stars', 'return']
# Title for Row 139 = ["'She", "'s", 'absolutely', 'steaming', "'", ':', 'House', 'Rules', "'", 'Johanna', 'Griggs', 'Jamie', 'Durie', "'s", 'bitter', 'rivalry', 'EXPOSED']
# Title for Row 140 = ['Russia', 'withdraws', 'key', 'defense', 'advisers', 'support', 'Maduro', ',', 'seen', 'major', 'setback', '-', 'Fox', 'News']
# Title for Row 141 = ['Prosperity', ',', 'repression', 'mark', 'China', '30', 'years', 'Tiananmen']
# Title for Row 142 = ['Senior', 'North', 'Korea', 'official', 'thought', 'imprisoned', 'Kim', 'Jong', 'Un', 'pictured', 'concert', 'dictator']
# Title for Row 143 = ['Top', 'North', 'Korean', 'official', 'reappears', 'days', 'purge', 'report']
# Title for Row 144 = ['Gillibrand', 'lights', 'NRA', "'worst", 'organization', 'country', "'", 'Fox', 'News', 'town', 'hall', '-', 'Fox', 'News']
# Title for Row 145 = ['The', 'Latest', ':', 'Trump', 'praises', 'Powells', ',', 'humorist', 'Russell', '-', 'Fox', 'News']
# Title for Row 146 = ['Kirsten', 'Gillibrand', 'town', 'hall', 'Fox', 'News', '--', 'live', 'blog', '-', 'Fox', 'News']
# Title for Row 147 = ['Legal', 'document', 'alleges', 'EU', 'migrant', "'crimes", 'humanity', "'"]
# Title for Row 148 = ["'Godzilla", ':', 'King', 'Monsters', "'", 'king', 'box', 'office', '-', 'Fox', 'News']
# Title for Row 149 = ['Lisa', 'Boothe']
# Title for Row 150 = ['Winning', 'ticket', '$', '344.6M', 'Powerball', 'jackpot', 'sold', 'North', 'Carolina', '-', 'Fox', 'News']
# Title for Row 151 = ['Canada', 'suspending', 'operations', 'embassy', 'Venezuela']
# Title for Row 152 = ['YouTube', 'star', 'gave', 'toothpaste-filled', 'Oreo', 'homeless', 'man', 'gets', '15-month', 'jail', 'sentence']
# Title for Row 153 = ['Nude', 'models', 'gather', 'NYC', 'protest', 'Facebook', 'Instagram', "'s", 'female', 'nipple', 'ban']
# Title for Row 154 = ['Hits', '&', 'Misses', ':', '6/1/19']
# Title for Row 155 = ['Car', 'bomb', 'rebel-held', 'northern', 'Syria', 'kills', '13', 'people']
# Title for Row 156 = ['What', 'US', 'blacklisting', 'Chinese', 'tech', 'giant', 'Huawei', 'mean', 'growing', 'trade', 'tensions', '?']
# Title for Row 157 = ['Pope', 'warns', 'EU', 'risks', 'future', "n't", 'confront', 'challenges']
# Title for Row 158 = ['Greek', 'conservatives', 'dominate', 'second', 'round', 'local', 'elections']
# Title for Row 159 = ['What', 'Mueller', 'really', 'trying', 'accomplish', 'statement', 'Russia', 'probe', '?']
# Title for Row 160 = ['KLM', 'CEO', 'Industry', 'Risks', ',', 'Brand', ',', 'Fleet', ',', "'Flying-V", "'", 'Concept']
# Title for Row 161 = ['In', 'Full', ':', 'China', "'s", 'White', 'Paper', 'U.S.', 'Economic', 'Trade', 'Talks']
# Title for Row 162 = ['Trump', 'Says', 'Economic', 'Adviser', 'Chair', 'Hassett', 'Leave', 'Job', 'Shortly', '-', 'Bloomberg']
# Title for Row 163 = ['Boeing', "'s", 'Max', '737', 'Is', 'Great', 'Plane', ',', 'Says', 'SpiceJet', "'s", 'Chairman']
# Title for Row 164 = ['Protesters', 'Topple', 'Statue', 'Ukraine']
# Title for Row 165 = ['World', "'s", 'Longest', 'Flight', 'Be', 'Even', 'Less', 'Comfortable', 'Than', 'Expected']
# Title for Row 166 = ['Top', 'North', 'Korean', 'Official', 'Reappears', 'Days', 'After', 'Purge', 'Report']
# Title for Row 167 = ['Trump', 'Set', 'Visit', 'U.K.', ';', 'Boosts', 'Johnson', 'Leader', 'Race']
# Title for Row 168 = ['Stock', 'Market', 'Today', ':', 'Dow', ',', 'S', '&', 'P', 'Live', 'Updates', 'June', '3', ',', '2019']
# Title for Row 169 = ['Global', 'Demand', 'For', 'Gold', 'Strong', '(', 'Radio', ')']
# Title for Row 170 = ["'Bloomberg", 'Daybreak', ':', 'Australia', "'", 'Full', 'Show', '(', '06/03/2019', ')']
# Title for Row 171 = ['Investors', 'Could', 'Tip', 'U.S.', 'Economy', 'Against', 'Themselves']
# Title for Row 172 = ['Boeing', 'Faces', 'Doubtful', 'Airline', 'Chiefs', 'Seoul', ':', 'IATA', 'Conference']
# Title for Row 173 = ['Kushner', 'Questions', 'Whether', 'Palestinians', 'Can', 'Govern', 'Themselves']
# Title for Row 174 = ['Libor', "'s", 'End', 'Forces', 'Global', 'Banks', 'Juggle', 'Multiple', 'Replacements']
# Title for Row 175 = ['Ongoing', 'Softness', 'Likely', 'For', 'Asian', 'Economy', '(', 'Radio', ')']
# Title for Row 176 = ['Australia', 'Property', 'Prices', 'Fall', 'Least', 'Year', 'Slide', 'Eases']
# Title for Row 177 = ['Underlying', 'Fundamentals', 'Still', 'Strong', 'For', 'Markets', '(', 'Radio', ')']
# Title for Row 178 = ['Trump', 'Sees', 'Immigration', 'Top', 'Political', 'Issue', ':', 'Hoover', 'Institution']
# Title for Row 179 = ['How', 'Would', 'Trump', "'s", 'Mexico', 'Tariffs', 'Affect', 'Automakers', '?']
# Title for Row 180 = ['Virginia', 'Beach', 'shooting', 'victim', 'died', 'trying', 'save', 'others']
# Title for Row 181 = ['The', 'Chairman', ',', 'Last', 'Shot', 'In', 'Oakland', ',', 'To', 'Kill', 'Mockingbird']
# Title for Row 182 = ['Boeing', 'warns', 'possible', 'wing', 'problems', '737', 'Max', 'planes']
# Title for Row 183 = ['Trump', 'says', 'top', 'economic', 'adviser', 'Kevin', 'Hassett', 'leaving']
# Title for Row 184 = ['Lake', 'Tahoe', 'waterfall', ':', 'Woman', 'dies', 'falling', 'Eagle', 'Falls', 'water', 'fall', 'near', 'North', 'Tahoe']
# Title for Row 185 = ['Swarm', 'bees', 'delays', 'MLB', 'game', 'San', 'Diego']
# Title for Row 186 = ['Obama', 'attends', 'NBA', 'Finals', 'Game', '2', 'Toronto']
# Title for Row 187 = ['Off-duty', 'Philly', 'firefighter', 'dies', 'triathlon', 'New', 'Jersey']
# Title for Row 188 = ['Off-duty', 'Philly', 'firefighter', 'dies', 'triathlon', 'New', 'Jersey']
# Title for Row 189 = ['6/2', ':', 'CBS', 'Evening', 'News']
# Title for Row 190 = ['Donald', 'Trump', 'U.K.', ':', 'President', "'s", 'trip', 'Britain', 'presents', 'security', 'challenges']
# Title for Row 191 = ['2', 'men', 'try', 'explain', 'meaning', 'Islam', 'country']
# Title for Row 192 = ['Jerome', 'Powell', ':', 'The', '60', 'Minutes', 'Interview']
# Title for Row 193 = ['What', 'goes', 'Golden', 'State', "'s", 'dynasty']
# Title for Row 194 = ['``', 'To', 'Kill', 'Mockingbird', "''", 'comes', 'Broadway']
# Title for Row 195 = ['Jeff', 'Daniels', ':', 'From', '``', 'Dumb', 'Dumber', "''", '``', 'To', 'Kill', 'Mockingbird', "''"]
# Title for Row 196 = ['The', 'talent', 'mindset', 'behind', 'Golden', 'State', 'Warriors', "'", 'dynasty']
# Title for Row 197 = ['``', 'To', 'Kill', 'Mockingbird', "''", 'comes', 'Broadway']
# Title for Row 198 = ['Federal', 'Reserve', 'Chairman', 'Jerome', 'Powell', ':', 'The', '60', 'Minutes', 'interview']
# Title for Row 199 = ['Texas', 'high', 'school', 'students', 'bringing', 'BBQ', 'new', 'level']
# Title for Row 200 = ['China', 'Is', 'Creating', 'A', '“', 'Greater', 'Bay', 'Area', '”', 'To', 'Rival', 'Silicon', 'Valley', '.', 'What', 'Will', 'It', 'Mean', 'Hong', 'Kong', '?']
# Title for Row 201 = ['WWDC', 'Preview', ':', 'How', 'Tim', 'Cook', 'Plans', 'Keep', 'Apple', 'Watch', 'Healthy', 'Business', 'Consumers']
# Title for Row 202 = ['‘', 'Deceit', 'Lies', 'Obstruction', 'Justice', '’', ':', '2020', 'Democratic', 'Candidates', 'Split', 'With', 'Pelosi', 'Impeachment']
# Title for Row 203 = ['5', 'Questions', 'Apple', 'Should', 'Answer', 'WWDC', '2019']
# Title for Row 204 = ['Fauna', 'Mexico', '’', 'Valle', 'de', 'Guadalupe', 'Is', 'Serving', 'Classic', 'Dishes', 'Better', 'Than', 'Anywhere', 'Else']
# Title for Row 205 = ['The', 'Roy', 'Rogers', 'Revival', 'Is', 'Fueled', 'Roadside', 'Rest', 'Stops', 'Its', 'Classic', 'Menu']
# Title for Row 206 = ['On', '‘', 'New', 'Silk', 'Road', ',', '’', 'Father-Son', 'Road', 'Trip', 'Goes', '8,000', 'Miles', 'China', 'Back']
# Title for Row 207 = ['Trump', 'Threatened', 'Mexico', 'With', 'Tariffs', ',', 'But', 'His', 'Demands', 'Are', 'Vague']
# Title for Row 208 = ['75', 'Executives', 'Lobbied', 'Congress', 'National', 'Carbon', 'Price', '.', 'We', 'Listened']
# Title for Row 209 = ['Baltimore', '’', 'Ransomware', 'Mess', 'Is', 'Its', 'Own', 'Fault—Cyber', 'Saturday']
# Title for Row 210 = ['Apple', 'Goes', 'Back', 'Time', 'With', 'IPod', 'Touch', 'Ahead', 'WWDC', '2019']
# Title for Row 211 = ['This', 'Island', 'Escape', 'Is', 'Italy', '’', 'Best-Kept', 'Secret']
# Title for Row 212 = ['The', 'Long', 'Winter', ':', 'Bracing', 'Protracted', 'US-China', 'Cold', 'War']
# Title for Row 213 = ['This', 'Trailblazer', 'Wants', 'Bring', 'Sake', 'Trail', 'Arkansas']
# Title for Row 214 = ['Japan', '’', 'Sake', 'Makers', 'Look', 'Wine', 'Define', 'Craft', 'Brews', 'Region']
# Title for Row 215 = ['To', 'Combat', 'Food', 'Waste', ',', 'These', 'Brooklyn', 'Businesses', 'Teamed', 'Up', 'Brew', 'Bagel', 'Beer']
# Title for Row 216 = ['A.I', '.', 'Hire', ':', '4', 'Ways', 'Algorithms', 'Can', 'Boost', 'Diversity', 'Hiring']
# Title for Row 217 = ['7', 'Books', 'Business', 'Journalism', 'You', 'Should', 'Read', 'This', 'Summer']
# Title for Row 218 = ['Fortune', 'Magazine', 'Masthead', ':', 'June', '1', ',', '2019', '(', 'Vol', '.', '179', ',', 'No', '.', '6', ')']
# Title for Row 219 = ['Grail', 'Touts', 'Its', 'Blood', 'Test', 'Detecting', 'Cancer', 'Early', ':', 'Brainstorm', 'Health']
# Title for Row 220 = ['Ex-Miami', 'school', 'board', 'member', ',', '81', ',', 'shoots', 'police', 'chase']
# Title for Row 221 = ['Heavy', 'machine', 'gun', 'fire', 'heard', 'Sudan', "'s", 'military', 'moves', 'sit-in', 'protest', 'capital', ',', 'Khartoum']
# Title for Row 222 = ['Mexicans', 'launch', 'friendly', 'defensive', 'deflect', 'US', 'tariffs']
# Title for Row 223 = ['Mexicans', 'launch', 'friendly', 'defensive', 'deflect', 'US', 'tariffs']
# Title for Row 224 = ['Today', 'History']
# Title for Row 225 = ['17-year-old', 'girl', 'wounded', 'shark', 'attack']
# Title for Row 226 = ['Trump', 'says', 'top', 'White', 'House', 'economist', 'Kevin', 'Hassett', 'leaving']
# Title for Row 227 = ['Prosperity', ',', 'repression', 'mark', 'China', '30', 'years', 'Tiananmen']
# Title for Row 228 = ['Chicago', 'police', 'investigating', "'unauthorized", "'", 'video', 'release']
# Title for Row 229 = ['10', 'dead', ',', 'least', '35', 'wounded', 'Chicago', 'since', 'Friday']
# Title for Row 230 = ['Trump', ':', "'Not", 'happy', "'", "'messed", "'", 'Israeli', 'politics']
# Title for Row 231 = ['Top', 'North', 'Korean', 'official', 'reappears', 'days', 'purge', 'report']
# Title for Row 232 = ['Illinois', 'House', 'skirts', 'salary-freeze', ',', 'set', 'pay', 'increase']
# Title for Row 233 = ['Boeing', 'notifies', 'FAA', 'improperly', 'made', 'parts', '737', 'Max']
# Title for Row 234 = ['Legal', 'document', 'alleges', 'EU', 'migrant', "'crimes", 'humanity', "'"]
# Title for Row 235 = ['China', 'blames', 'US', 'trade', 'dispute', ',', "n't", 'escalate']
# Title for Row 236 = ['Toddler', 'falls', 'coma', 'tick', 'bite']
# Title for Row 237 = ['Nobody', 'hurt', 'California', 'gas', 'blast', 'rattled', 'buildings']
# Title for Row 238 = ['Boeing', 'warns', 'potential', 'wing', 'problems', '737', 'aircraft']
# Title for Row 239 = ['Dwyane', 'Wade', 'surprises', 'Parkland', 'high', 'school', 'graduates']
# Title for Row 240 = ['Atacante', 'Benfica', 'que', 'fez', '51', 'gols', 'em', '29', 'jogos', 'em', '2019', ',', 'Geyse', 'é', 'revelação', 'da', 'seleção']
# Title for Row 241 = ['Atacante', 'Benfica', 'que', 'fez', '51', 'gols', 'em', '29', 'jogos', 'em', '2019', ',', 'Geyse', 'é', 'revelação', 'da', 'seleção']
# Title for Row 242 = ['Tiroteio', 'assusta', 'moradores', 'na', 'região', 'de', 'Quintino', 'e', 'Água', 'Santa']
# Title for Row 243 = ['Bolsonaro', 'promete', 'apresentar', 'nesta', 'semana', 'projeto', 'para', 'aumentar', 'validade', 'da', 'carteira', 'de', 'motorista']
# Title for Row 244 = ['Estátua', "'Os", 'Escoteiros', "'", 'é', 'encontrada', 'na', 'Marina', 'da', 'Gloria']
# Title for Row 245 = ['Valinhos', 'inicia', 'fiscalização', 'com', 'radares', 'eletrônicos', 'e', 'pontos', 'de', 'controle', 'de', 'velocidade']
# Title for Row 246 = ['Morre', 'atriz', 'Gabi', 'Costa', ',', 'Nazira', 'de', "'Órfãos", 'da', 'Terra', "'", ',', 'aos', '33', 'anos', 'Rio']
# Title for Row 247 = ['Desfalcado', 'e', 'com', 'um', 'menos', ',', 'Fluminense', 'joga', 'mal', 'e', 'é', 'derrotado', 'pelo', 'Athletico']
# Title for Row 248 = ['Advogada', 'encontrada', 'morta', 'em', 'Nova', 'Iguaçu', 'será', 'enterrada', 'nesta', 'segunda-feira']
# Title for Row 249 = ['Jovem', 'encontrada', 'morta', 'em', 'Nova', 'Iguaçu', 'será', 'enterrada', 'nesta', 'segunda-feira']
# Title for Row 250 = ['Advogada', 'desaparecida', 'será', 'enterrada', 'em', 'Nova', 'Iguaçu']
# Title for Row 251 = ['O', 'que', 'se', 'viu', 'de', 'Neymar', 'treino', 'da', 'seleção', 'brasileira', 'após', 'acusação', 'de', 'estupro']
# Title for Row 252 = ['Jogadores', 'da', 'seleção', 'brasileira', 'darão', 'apoio', 'Neymar', ',', 'diz', 'Fernandinho']
# Title for Row 253 = ['Acidente', 'de', 'barco', 'na', 'costa', 'da', 'Líbia', 'deixa', 'ao', 'menos', 'dois', 'imigrantes', 'mortos', ',', '25', 'desaparecidos']
# Title for Row 254 = ['Andy', 'Ruiz', 'nocauteia', 'Joshua', ',', 'conquista', 'quatro', 'cinturões', 'e', 'faz', 'história', 'Boxe']
# Title for Row 255 = ['Prefeitura', 'de', 'Campinas', 'abre', '80', 'vagas', 'para', 'oficina', 'de', 'capoeira', 'e', 'cultura', 'afro-brasileira']
# Title for Row 256 = ['Primeira', 'chuva', 'forte', 'desde', 'interdição', 'da', 'Niemeyer', 'preocupa', 'moradores', 'Vidigal']
# Title for Row 257 = ['Assessor', 'de', 'Trump', 'diz', 'que', 'tarifas', 'sobre', 'México', 'não', 'vão', 'atrapalhar', 'acordo', 'comercial']
# Title for Row 258 = ['Jogadores', 'da', 'seleção', 'saem', 'em', 'defesa', 'de', 'Neymar', ':', "'Nome", 'está', 'em', 'jogo', "'"]
# Title for Row 259 = ['Chefe', 'Pentágono', 'diz', 'não', 'haver', 'necessidade', 'de', 'restaurar', 'exercícios', 'militares', 'dos', 'EUA', 'e', 'Coreia', 'Sul']
# Title for Row 260 = ['Top', 'White', 'House', 'economic', 'adviser', 'leaving', ',', 'Trump', 'says']
# Title for Row 261 = ['Rhode', 'Island', 'bishop', 'defends', 'call', 'boycott', 'Pride', 'events']
# Title for Row 262 = ['Virginia', 'Beach', 'shooter', 'notified', 'boss', 'plans', 'leave', 'job']
# Title for Row 263 = ['Aspiring', 'doctors', 'learn', 'zoo', 'unique', 'medical', 'school', 'program']
# Title for Row 264 = ['Woman', 'swept', 'away', 'waterfall', 'reaching', 'branch', ',', 'taking', 'photos']
# Title for Row 265 = ['Inside', 'scientists', '’', 'new', 'plan', 'deflect', 'asteroids', 'away', 'Earth']
# Title for Row 266 = ['Texas', 'latest', 'state', 'ban', 'red', 'light', 'cameras']
# Title for Row 267 = ['2020', 'candidate', 'security', 'concerns', 'protester', 'storms', 'stage', 'Sen.', 'Harris']
# Title for Row 268 = ['Google', 'confirms', 'big', 'outage', 'YouTube', ',', 'GMail', ',', 'major', 'services']
# Title for Row 269 = ['Trump', 'denies', 'comment', 'Meghan', 'Markle', 'recorded', 'interview', 'ahead', 'UK', 'visit']
# Title for Row 270 = ['Injuries', 'cruise', 'ship', 'plows', 'Venice', 'dock']
# Title for Row 271 = ['Estranged', 'husband', 'girlfriend', 'arrested', 'Connecticut', 'mom', 'vanishes']
# Title for Row 272 = ['Swollen', 'rivers', 'flood', 'homes', ',', 'force', 'evacuations', 'several', 'states']
# Title for Row 273 = ['Gunman', 'submitted', 'resignation', 'hours', 'Virginia', 'Beach', 'shooting', ',', 'authorities', 'say']
# Title for Row 274 = ['Virginia', 'Beach', 'authorities', 'provide', 'timeline', 'fatal', 'mass', 'shooting']
# Title for Row 275 = ['Sanders', 'jabs', 'Biden', 'attending', 'California', 'Democratic', 'convention']
# Title for Row 276 = ['Woman', 'called', 'Michelle', 'Obama', "'ape", "'", 'sentenced', 'jail', 'defrauding', 'FEMA', '$', '18K']
# Title for Row 277 = ['China', 'releases', 'official', 'document', 'blaming', 'America', 'trade', 'war']
# Title for Row 278 = ['Ahead', 'D-Day', ',', 'Trump', 'storms', 'Europe']
# Title for Row 279 = ['Shanahan', 'tells', 'White', 'House', 'office', 'politicize', 'military']
# Title for Row 280 = ['Top', 'Shot', ':', 'In', 'Oil', 'Lamp', 'Light', 'Top', 'Shot', 'features', 'photo', '...']
# Title for Row 281 = ['Top', 'Shot', ':', 'Little', 'Kits', 'Prairie', 'Top', 'Shot', 'features', '...']
# Title for Row 282 = ['Top', 'Shot', ':', 'Come', 'Mama', 'Top', 'Shot', 'features', 'photo', '...']
# Title for Row 283 = ['Top', 'Shot', ':', 'Ellison', '’', 'Cave', 'Top', 'Shot', 'features', 'photo', '...']
# Title for Row 284 = ['Top', 'Shot', ':', 'Underwater', 'Light', 'Show', 'Top', 'Shot', 'features', 'photo', '...']
# Title for Row 285 = ['In', 'first', ',', 'chimpanzees', 'seen', 'smashing', 'eating', 'tortoises']
# Title for Row 286 = ['Top', 'Shot', ':', 'True', 'Love', 'Top', 'Shot', 'features', 'photo', '...']
# Title for Row 287 = ['Last', 'American', 'Slave', 'Ship', 'Is', 'Discovered', 'In', 'Alabama']
# Title for Row 288 = ['This', 'Is', 'The', 'World', "'s", 'Rarest', 'Form', 'Of', 'Gold', '.', 'New', 'Clues', 'Are', 'Revealing', 'Why']
# Title for Row 289 = ['Eating', 'dead', 'marine', 'animals', 'becoming', 'public', 'health', 'hazard']
# Title for Row 290 = ['Top', 'Shot', ':', 'Just', 'Little', 'Shake', 'Top', 'Shot', 'features', 'photo', '...']
# Title for Row 291 = ['Your', 'Story', ':', 'Monika', 'Kalmar', 'In', 'Your', 'Story', 'feature', ',', 'ask', '...']
# Title for Row 292 = ['Strange', 'Waves', 'Rippled', 'Around', 'Earth', '.', 'Now', 'We', 'May', 'Know', 'Why']
# Title for Row 293 = ['Giant', 'tiger', 'sharks', 'eat', 'backyard', 'birds', ',', 'surprising', 'study', 'reveals', '-', 'National', 'Geographic']
# Title for Row 294 = ['Top', 'Shot', ':', 'Highway', 'Heaven', 'Top', 'Shot', 'features', 'photo', '...']
# Title for Row 295 = ['Tornadoes', ':', 'The', 'science', 'behind', 'destruction']
# Title for Row 296 = ['Top', 'Shot', ':', 'Moment', 'Love', 'Top', 'Shot', 'features', 'photo', '...']
# Title for Row 297 = ['The', 'Volcano', 'That', 'Built', 'Bermuda', 'Is', 'Unlike', 'Any', 'Other', 'On', 'Earth']
# Title for Row 298 = ['Top', 'Shot', ':', 'Midnight', 'Moving', 'Day', 'Top', 'Shot', 'features', 'photo', '...']
# Title for Row 299 = ['See', 'The', 'Face', 'Of', 'A', 'Man', 'From', 'The', 'Last', 'Gasps', 'Of', 'The', 'Roman', 'Empire']
# Title for Row 300 = ['Rep.', 'Bennie', 'Thompson', ':', 'Impeachment', "'absolutely", "'", 'inevitable']
# Title for Row 301 = ['Planned', 'Parenthood', 'President', ':', "'We", 'state', 'emergency', "'"]
# Title for Row 302 = ['Elbows', 'get', 'sharper', 'among', '2020', 'Democrats', 'debate', 'stage', 'looms']
# Title for Row 303 = ['Timing', 'everything', ':', 'How', 'order', 'Mueller', 'report', '’', 'release', 'shaped', 'public', 'opinion']
# Title for Row 304 = ['Prof.', 'Kendi', 'talks', 'article', 'benefactor', 'Robert', 'Smith']
# Title for Row 305 = ['Texas', 'secretary', 'state', 'resigns', 'failed', 'voter', 'purge', 'effort']
# Title for Row 306 = ['Jaime', 'Harrison', 'challenges', 'Lindsey', 'Graham', 'Senate', '2020']
# Title for Row 307 = ['Protester', 'grabbing', 'mic', 'Harris', 'called', '‘', 'affront', 'democracy', '’']
# Title for Row 308 = ['Former', 'Watergate', 'prosecutor', 'says', 'public', 'needs', 'televised', 'hearings']
# Title for Row 309 = ['‘', 'When', 'They', 'See', 'Us', '’', 'revisits', 'criminal', 'justice', 'failures', 'relevant']
# Title for Row 310 = ['GOP', 'may', 'evade', 'Mueller', '’', 'findings', 'long', 'Dems', '’', 'impeach']
# Title for Row 311 = ['Rep.', 'Dingell', 'gun', 'control', ',', 'possible', 'Trump', 'impeachment']
# Title for Row 312 = ['Televangelist', 'refuses', 'fly', 'commercial', "'demons", "'", 'calls', 'national', 'day', 'prayer', 'Trump']
# Title for Row 313 = ['Trump', 'slams', 'Biden', '’', 'role', '1994', 'crime', 'bill']
# Title for Row 314 = ['DNC', 'Chair', 'Perez', 'impeachment', ':', '“', 'We', 'must', 'continue', 'gather', 'facts', "''"]
# Title for Row 315 = ['What', 'reality', 'impeachment', 'becoming', 'possibility', '?']
# Title for Row 316 = ['Watch', ':', 'Protester', 'rushes', 'stage', ',', 'grabs', 'mic', 'Sen.', 'Kamala', 'Harris']
# Title for Row 317 = ['Rep.', 'Raskin', ':', "'The", 'lawlessness', 'corruption', 'presidency', 'contaminating', 'everything', "'"]
# Title for Row 318 = ['New', 'York', 'Times', 'columnist', ':', 'Mueller', 'believes', '’', 'evidence', 'obstruction', ',', 'say', 'Congress']
# Title for Row 319 = ['Former', 'US', 'Attorney', 'Michael', 'Flynn', ':', 'When', 'judge', 'orders', 'produce', 'something', ',', '“', 'expectation', '’', 'produce', '”']
# Title for Row 320 = ['Britain', "'s", 'Got', 'Talent', 'finale', ':', 'Dave', 'Finn', 'surprised', 'vet']
# Title for Row 321 = ['Tom', 'Ellis', 'joined', 'Lucifer', 'co-stars', 'marries', 'Meaghan', 'Oppenheimer']
# Title for Row 322 = ['Student', 'creates', 'towel', 'help', 'resuscitate', 'babies', 'stop', 'breathing']
# Title for Row 323 = ['Ruth', 'Langsford', "'not", 'drunk', "'", 'nasty', 'fall', 'left', 'knees', 'bloody']
# Title for Row 324 = ['You', 'Do', "n't", 'Look', 'Sick', ':', 'Endometriosis', 'polycystic', 'ovary', 'syndrome', '.']
# Title for Row 325 = ['BTS', "'", 'Jungkook', "'feels", 'guilty', "'", 'apologises', 'heel', 'injury', 'last', 'tour']
# Title for Row 326 = ['Ninja', 'Warrior', 'UK', 'contestant', 'Tim', 'Champion', 'makes', 'history', 'first', 'winner', 'five', 'years']
# Title for Row 327 = ['BTS', 'star', 'RM', 'pays', 'moving', 'tribute', 'Korean', 'tourist', 'Hungary', 'boat', 'crash']
# Title for Row 328 = ['BTS', 'star', 'RM', 'admits', 'K-Pop', 'band', "'too", 'much', "'", 'ahead', 'London', 'concert']
# Title for Row 329 = ['Letting', 'agency', 'fees', 'illegal', 'today']
# Title for Row 330 = ["'Epidemic", "'", 'bugging', 'devices', 'used', 'stalkers', '...']
# Title for Row 331 = ['Boy', 'doctors', "n't", 'think', 'would', 'live', 'celebrates', 'fifth', 'birthday']
# Title for Row 332 = ['Company', 'offers', 'female', 'employees', 'money', 'wear', 'short', 'skirts', 'office']
# Title for Row 333 = ['Donald', 'Trump', '£25,000,000', 'security', 'operation', 'UK', 'state', 'visit']
# Title for Row 334 = ["'Record", 'number', "'", 'migrant', 'boats', 'spotted', 'Kent', 'coast', 'ongoing', 'incident']
# Title for Row 335 = ['Student', 'left', 'chemical', 'burn', 'eye', 'using', 'micellar', 'water']
# Title for Row 336 = ['Donald', 'Trump', 'backs', 'Boris', 'Johnson', 'next', 'UK', 'Prime', 'Minister']
# Title for Row 337 = ['Hidden', 'camera', "'caught", 'huntsman', 'feeding', 'live', 'fox', 'cubs', 'dogs', "'"]
# Title for Row 338 = ["'Sharing", 'forfeits', 'right', "'", '...']
# Title for Row 339 = ['Mysterious', 'flashes', 'light', 'observed', 'moon', '...']
# Title for Row 340 = ['News24.com', '|', 'Ramaphosa', 'pleases', ',', 'inspires', 'disappoints']
# Title for Row 341 = ['News24.com', '|', 'Trumps', 'heads', 'UK', '|', 'Man', 'faced', 'mass', 'killer', ':', 'WATCH', 'top', 'World', 'news', 'videos', 'Monday']
# Title for Row 342 = ['News24.com', '|', 'Qatar', 'rejects', 'Mecca', 'talks', 'outcome']
# Title for Row 343 = ['News24.com', '|', 'Judgment', 'remaining', 'Krugersdorp', 'killers', 'heard']
# Title for Row 344 = ['News24.com', '|', 'Ace', 'Magashule', 'taken', 'task', 'Cyril', 'Ramaphosa', 'flexes', 'muscles']
# Title for Row 345 = ['News24.com', '|', 'Fake', 'soldier', 'causes', 'panic', 'infiltrating', 'SANDF']
# Title for Row 346 = ['News24.com', '|', 'Afriforum', "'s", 'threat', 'EFF', 'unpaid', 'R109k', ':', 'Pay', 'seize', 'assets']
# Title for Row 347 = ['News24.com', '|', 'Train', 'services', 'back', 'track', 'Pretoria', '–', 'Metrorail']
# Title for Row 348 = ['News24.com', '|', 'Four', 'rescued', ',', '8', 'still', 'missing', 'avalanche-hit', 'Indian', 'peak']
# Title for Row 349 = ['News24.com', '|', 'Speed', 'probe', 'Mamelodi', 'rail', 'collision', '-', 'new', 'minister', 'Mbalula', "'s", "'baptism", 'fire', "'"]
# Title for Row 350 = ['Monday', "'s", 'weather', ':', 'The', 'week', 'starts', 'fine', 'cool']
# Title for Row 351 = ['News24.com', '|', 'WATCH', ':', 'Life', 'Inside', 'Jail', '-', 'Hell', 'Earth']
# Title for Row 352 = ['News24.com', '|', "'Hero", 'paramedic', "'", 'rescues', 'elderly', 'woman', 'building', 'fire', 'Durban']
# Title for Row 353 = ['News24.com', '|', 'On', 'eve', 'UK', 'visit', ',', 'Trump', 'denies', 'taped', 'remark', "'nasty", "'", 'Meghan', 'Markle']
# Title for Row 354 = ['News24.com', '|', 'IFP', 'mourns', 'senior', 'leader', 'Sibongile', 'Nkomo']
# Title for Row 355 = ['News24.com', '|', 'Former', 'Botswana', 'president', 'Ian', 'Khama', 'might', 'returning']
# Title for Row 356 = ['News24.com', '|', 'Barbara', 'Creecy', 'build', 'work', 'predecessors', 'inherits', 'department', '‘', 'good', 'shape', '’']
# Title for Row 357 = ['News24.com', '|', 'Woman', 'killed', 'Worcester', 'store', 'shooting']
# Title for Row 358 = ['News24.com', '|', "'Father", 'democracy', "'", ':', 'DRC', "'s", 'Etienne', 'Tshisekedi', 'laid', 'rest']
# Title for Row 359 = ['News24.com', '|', '4', 'Mamelodi', 'Hospital', 'staffers', 'implicated', 'tying', '76-year-old', 'bench', '-', 'MEC']
# Title for Row 360 = ['Ranking', ':', 'Das', 'sind', 'die', 'ältesten', 'Familienunternehmen', 'Deutschlands']
# Title for Row 361 = ['Nachgefragt', 'bei', 'Stefan', 'Heidbreder', ':', '„', 'Familienunternehmen', 'sind', 'die', 'wirtschaftliche', 'Pulsader', 'Deutschlands', '“']
# Title for Row 362 = ['Wirtschaft', ',', 'Handel', '&', 'Finanzen', ':', 'Apple', 'gibt', 'bei', 'Entwicklerkonferenz', 'WWDC', 'Ausblick', 'auf', 'neue', 'Software', '-', 'Handelsblatt']
# Title for Row 363 = ['Chef', 'des', 'Wirtschaftsberaterrats', ':', 'Trump', 'kündigt', 'Rücktritt', 'von', 'Top-Ökonom', 'Kevin', 'Hassett']
# Title for Row 364 = ['Chiphersteller', ':', 'Infineon', 'offenbar', 'vor', 'Übernahme', 'von', 'Cypress', 'Semiconductor']
# Title for Row 365 = ['Nikkei', ',', 'Topix', '&', 'Co.', ':', 'Tokioter', 'Börse', 'startet', 'im', 'Minus', 'die', 'Woche']
# Title for Row 366 = ['US-Außenminister', ':', 'Pompeo', 'zweifelt', 'Erfolg', 'von', 'Nahost-Friedensplan']
# Title for Row 367 = ['Syrien', ':', 'Trump', 'fordert', 'Ende', 'der', 'Bombenangriffe', 'auf', 'Idlib']
# Title for Row 368 = ['Luftfahrtbranche', ':', 'Preisdruck', ',', 'teures', 'Kerosin', ',', 'Konjunkturschwäche', '–', 'Airlines', 'droht', 'ein', 'bitteres', 'Jahr']
# Title for Row 369 = ['Staatsbesuch', 'Großbritannien', ':', 'Trump', 'plant', 'mögliches', 'Treffen', 'mit', 'Boris', 'Johnson', 'und', 'Nigel', 'Farage']
# Title for Row 370 = ['Bankenbranche', ':', 'Solarisbank-Gründer', 'Marko', 'Wenthin', 'wird', 'Chef', 'von', 'Online-Geschäftsbank', 'Penta']
# Title for Row 371 = ['Nahles-Rücktritt', 'und', 'die', 'Folgen', ':', 'Große', 'Koalition', 'vor', 'dem', 'Aus', '?', 'Diese', 'Szenarien', 'sind', 'möglich']
# Title for Row 372 = ['Ab', 'Sommer', '2019', ':', 'Neues', 'Krisen-Lagezentrum', 'soll', 'Analysen', 'für', 'das', 'Kanzleramt', 'erstellen']
# Title for Row 373 = ['Nordkorea', ':', 'USA', ',', 'Japan', 'und', 'Südkorea', 'erneuern', 'Bekenntnis', 'zu', 'Atomabrüstung', 'Korea']
# Title for Row 374 = ['Luftfahrt', ':', 'US-Flugaufsicht', 'fordert', 'Austausch', 'von', 'Teilen', 'der', 'Boeing', '737', 'Max']
# Title for Row 375 = ['Walter', 'Lübcke', ':', 'Der', 'Tod', 'des', 'Kasseler', 'Regierungspräsidenten', 'gibt', 'Rätsel', 'auf']
# Title for Row 376 = ['Krise', 'Venezuela', ':', 'Kanada', 'stoppt', 'vorübergehend', 'Betrieb', 'von', 'Botschaft', 'Venezuela']
# Title for Row 377 = ['Frankreich', ':', 'Paris', 'ändert', 'seine', 'Meinung', 'über', 'das', 'EU-Wettbewerbsrecht', '–', 'und', 'lobt', 'Brüssel']
# Title for Row 378 = ['Problem', 'mir', 'Google', 'Cloud', ':', 'Massive', 'Störung', 'bei', 'mehreren', 'Google-Diensten']
# Title for Row 379 = ['CDU-Vorstandsklausur', ':', 'Kramp-Karrenbauer', 'warnt', 'vor', 'Machtverlust']
# Title for Row 380 = ['Amazon', "'s", 'Good', 'Omens', 'Miniseries', 'Review']
# Title for Row 381 = ['Amazon', "'s", 'Good', 'Omens', 'Miniseries', 'Review']
# Title for Row 382 = ['Toy', 'Story', '4', "'", 'é', 'uma', 'metáfora', 'para', 'futuro', 'da', 'Pixar', "'", ',', 'diz', 'produtor']
# Title for Row 383 = ['Cuphead', 'pode', 'ser', 'jogado', 'em', 'carros', 'Tesla']
# Title for Row 384 = ['E3', '2019', ':', 'Quais', 'games', 'e', 'novidades', 'queremos', 'ver', '?']
# Title for Row 385 = ['Artista', 'de', 'Detetive', 'Pikachu', 'compartilha', 'arte', 'conceitual', 'de', 'cena', 'não', 'utilizada']
# Title for Row 386 = ['Por', 'que', 'cooperativo', 'local', 'precisa', 'voltar', 'ser', 'algo', 'comum', 'nos', 'games']
# Title for Row 387 = ['Overwatch', ':', 'Brasileiros', 'jogam', 'mais', 'como', 'suporte', ',', 'diz', 'Blizzard']
# Title for Row 388 = ['D', '&', 'D', 'Classics', 'Enhanced', 'Editions', '-', 'Console', 'Trailer']
# Title for Row 389 = ['Baldur', "'s", 'Gate', 'e', 'outros', 'RPGs', 'clássicos', 'vão', 'chegar', 'para', 'consoles']
# Title for Row 390 = ['Daily', 'Deals', ':', 'Cheap', 'Bluetooth', 'Speakers', ',', 'Death', 'Stranding', 'Preorders', '4K', 'TVs']
# Title for Row 391 = ['Daily', 'Deals', ':', 'Cheap', 'Bluetooth', 'Speakers', ',', 'Death', 'Stranding', 'Preorders', '4K', 'TVs']
# Title for Row 392 = ['Chernobyl', ':', 'Minissérie', 'da', 'HBO', 'seduz', 'público', 'com', 'bastidores', 'de', 'tragédia', 'nuclear', 'histórica']
# Title for Row 393 = ['Minecraft', ':', 'Story', 'Mode', 'se', 'eliminará', 'finales', 'de', 'mes']
# Title for Row 394 = ['Pokémon', 'Go', 'dejará', 'de', 'funcionar', 'en', 'su', 'versión', 'de', 'Apple', 'Watch']
# Title for Row 395 = ['Godzilla', ':', 'Rey', 'de', 'los', 'Monstruos', 'lidera', 'la', 'taquilla', 'con', 'una', 'recaudación', 'moderada']
# Title for Row 396 = ['Todd', 'Howard', 'Says', 'Bethesda', 'Knew', 'Fallout', '76', "'Would", 'Have', 'Bumps', "'"]
# Title for Row 397 = ['Shinji', 'Mikami', 'podría', 'presentar', 'algún', 'juego', 'en', 'el', 'E3', '2019']
# Title for Row 398 = ['Netflix', 'subirá', 'de', 'precio', 'en', 'el', 'Reino', 'Unido']
# Title for Row 399 = ['Which', 'Game', 'Thrones', 'Season', 'Is', 'Best', '?']
# Title for Row 400 = ['Boris', 'Johnson', 'vows', 'increase', 'secondary', 'school', 'spending', '£5,000', 'per', 'pupil', 'England']
# Title for Row 401 = ['Drinking', '25', 'cups', 'coffee', 'day', 'safe', 'heart', ',', 'study', 'finds']
# Title for Row 402 = ['Tory', 'leadership', 'contenders', 'suggest', 'government', 'U-turn', 'Huawei', 'ahead', 'Trump', 'visit']
# Title for Row 403 = ['Priyanka', 'Chopra', 'says', "'of", 'course', "'", 'racism', 'blame', 'scrutiny', 'Meghan', 'Markle']
# Title for Row 404 = ['Weight', 'loss', 'drink', 'company', 'reported', 'advertising', 'watchdog', 'diabetes', "'blood", 'sugar', 'reduction', "'", 'claim']
# Title for Row 405 = ['UK', 'weather', 'forecast', ':', 'Britain', 'enjoys', 'hottest', 'day', 'year', 'far', 'temperatures', 'hit', '28C']
# Title for Row 406 = ['Two', 'French', 'Isis', 'members', 'sentenced', 'death', 'Iraq']
# Title for Row 407 = ['Trump', 'administration', 'cuts', 'funding', 'anti-Iran', 'group', 'trolls', 'human', 'rights', 'activists']
# Title for Row 408 = ["'We", "'ve", 'become', 'kind', 'family', "'", ':', 'The', 'unlikely', 'network', 'survivors', 'devastated', 'US', 'mass', 'shootings']
# Title for Row 409 = ['Two', 'five-year-olds', 'swept', 'half', 'mile', 'sea', 'inflatable', 'swan']
# Title for Row 410 = ['Amazon', 'could', 'face', 'heightened', 'scrutiny', 'Trump', 'administration', 'new', 'deal']
# Title for Row 411 = ['Four-year-old', 'child', 'skateboard', 'dies', 'hit', 'van', 'Surrey']
# Title for Row 412 = ['Google', ':', 'Internet', 'stops', 'working', 'properly', 'YouTube', ',', 'Snapchat', 'hit', 'major', 'outage']
# Title for Row 413 = ['Cory', 'Booker', ':', '2020', 'presidential', 'hopeful', 'compares', 'gun', 'control', 'fight', 'civil', 'rights', 'movement']
# Title for Row 414 = ['Daily', 'pill', 'could', 'help', 'men', 'advanced', 'prostate', 'cancer', ',', 'study', 'says']
# Title for Row 415 = ['EMBARGO', '22.30', 'Trump', 'visit', ':', 'Theresa', 'May', 'hails', 'chance', 'build', "'strong", 'enduring', 'ties', "'", 'UK', 'US', 'president', "'s", 'trip']
# Title for Row 416 = ['How', 'Owen', 'Farrell', 'inspired', 'Saracens', 'Premiership', 'final', 'comeback', 'even', 'surprise', 'boss', 'Mark', 'McCall']
# Title for Row 417 = ['Home', 'Office', 'sending', 'modern', 'slavery', 'victims', 'back', 'addresses', 'abused', ',', 'lawyers', 'warn']
# Title for Row 418 = ['Ann', 'Widdecombe', 'says', 'science', 'may', "'produce", 'answer', "'", 'gay']
# Title for Row 419 = ['Champions', 'League', 'trophy', 'parade', ':', 'More', 'half', 'million', 'take', 'Liverpool', "'s", 'streets', 'celebrate', 'triumph']
# Title for Row 420 = ['El', 'PRO', 'reunió', 'su', 'equipo', 'de', 'comunicación', 'marketing', 'en', 'Olivos', 'para', 'apuntalar', 'el', 'relato', 'de', 'campaña']
# Title for Row 421 = ['Lavagna', 'rechazó', 'el', 'acuerdo', 'planteado', 'por', 'el', 'Gobierno', ':', '``', 'Esto', 'es', 'consenso', ',', 'es', 'marketing', "''"]
# Title for Row 422 = ['Justiça', 'dá', 'decisão', 'favorável', 'Steinbruch', 'em', 'disputa', 'familiar']
# Title for Row 423 = ['Bolsonaro', 'diz', 'que', 'não', 'vai', 'e', 'que', 'não', 'tem', 'como', 'interferir', 'na', 'Petrobras']
# Title for Row 424 = ['Legislação', 'cria', "'banqueiro", 'individual', "'"]
# Title for Row 425 = ['O', 'melhor', 'dia', 'para', 'comprar', 'passagens', 'nacionais', 'para', 'férias', 'de', 'julho', 'e', 'pagar', 'menos']
# Title for Row 426 = ['CEO', 'Google', 'recusa', 'generoso', 'bônus', 'em', 'ações']
# ...
# Title for Row 592 = ['Daily', 'Horoscopes', ':', 'June', '1', ',', '2019']
# Title for Row 593 = ['China', "'s", 'Big', 'AI', 'Advantage', ':', 'Humans']
# Title for Row 594 = ['Raveena', "'s", 'Debut', 'Album', 'Is', 'Dreamy', 'R', '&', 'B', 'Universe']
# Title for Row 595 = ['The', 'Complex', 'Ethics', 'Saving', 'Dead', 'Person', "'s", 'Sperm']
# Title for Row 596 = ['meet', 'costume', 'designer', 'behind', 'outrageous', 'looks', "'rocketman", "'"]
# Title for Row 597 = ['GREAT', 'NEWS', ':', 'You', 'Can', 'Now', 'Pay', '$', '50', 'Hang', 'Out', 'Cafe', 'Full', 'Live', 'Rats']
# Title for Row 598 = ['It', "'s", 'Time', 'We', 'Admit', 'That', 'Tote', 'Bags', 'Are', 'Trash']
# Title for Row 599 = ['“', 'Very', 'Dangerous', 'Precedent', ':', '”', 'Ro', 'Khanna', 'Slams', 'Facebook', 'For', 'Deceptive', 'Nancy', 'Pelosi', 'Video']
# Title for Row 600 = ['Denzel', 'Curry', "'s", 'Energizing', 'Raps', '11', 'More', 'Albums', 'Heavy', 'Rotation']
# Title for Row 601 = ['They', '’', 'Not', 'Household', 'Names', ',', 'But', 'They', '’', 'Some', 'Household', 'Names']
# Title for Row 602 = ['Millions', 'Deaths', 'Later', ',', 'Someone', 'Beat', 'This', 'Nightmarish', "'Mario", 'Maker', "'", 'stage']
# Title for Row 603 = ['Hybrid', 'Ferraris', '!', 'Flying', 'Cars', '!', 'And', 'More', 'Car', 'News', 'This', 'Week']
# Title for Row 604 = ['Trump', "'s", 'Response', 'Robert', 'Mueller', 'Tops', 'This', 'Week', "'s", 'Internet', 'News', 'Roundup']
# Title for Row 605 = ['At', '90', ',', 'E.', 'O.', 'Wilson', 'Still', 'Thrives', 'Being', 'Scientific', 'Provocateur']
# Title for Row 606 = ['Cinder', 'Grill', 'Review', ':', 'Cooks', 'Like', 'Champ', ',', 'Needs', 'Refinement']
# Title for Row 607 = ['Much', '@', 'Stake', ':', 'The', 'Band', 'Hackers', 'That', 'Defined', 'Era']
# Title for Row 608 = ['Apple', 'Just', 'Patched', 'Modem', 'Bug', 'That', "'s", 'Been', 'Macs', 'Since', '1999']
# Title for Row 609 = ['Gadget', 'Lab', 'Podcast', ':', 'An', 'Interview', 'With', 'Firewire', 'Surfboards', 'CEO', 'Mark', 'Price']
# Title for Row 610 = ['Space', 'Photos', 'Week', ':', 'How', 'Stars', 'Get', '86', '’']
# Title for Row 611 = ['The', 'YouTuber', 'Mission', 'Save', 'Classic', 'RPG']
# Title for Row 612 = ['The', 'YouTuber', 'Mission', 'Save', 'Classic', 'RPG']
# Title for Row 613 = ['Security', 'News', 'This', 'Week', ':', 'A', 'Teen', 'Waltzed', 'Into', 'Mar-a-Lago']
# Title for Row 614 = ['An', 'Illicit', 'Chemical', 'Is', 'Again', 'Jeopardizing', 'Ozone', 'Layer']
# Title for Row 615 = ['15', 'Best', 'Weekend', 'Tech', 'Deals', ':', 'Laptops', ',', 'TVs', ',', 'Games', ',', 'More']
# Title for Row 616 = ['Why', 'Net', 'Neutrality', 'Advocates', 'Remain', 'Optimistic']
# Title for Row 617 = ['What', 'Amazon', 'Might', 'Want', 'With', 'Boost', 'Mobile']
# Title for Row 618 = ['The', 'Shenanigans', 'Behind', 'Stealthy', 'Apple', 'Keychain', 'Attack']
# Title for Row 619 = ['How', 'Group', 'Students', 'Built', 'Launched', 'Rocket', 'Space']
# Title for Row 620 = ['Foursquare', 'Is', 'Adding', 'Even', 'More', 'Data', 'About', 'Where', 'You', 'Are']
# Title for Row 621 = ["'Call", 'Duty', "'", 'Is', 'Here', ',', 'Apple', 'Updates', 'Are', 'Coming', ',', 'More', 'News']
# Title for Row 622 = ['At', 'French', 'Open', ',', 'Serena', 'Williams', 'Is', 'Study', 'Motion']
# Title for Row 623 = ['FAA称全球有312架波音737零部件或存在缺陷', '-', '华尔街日报中文网']
# Title for Row 624 = ['Google', 'Gets', 'Ready', 'Legal', 'Fight', 'As', 'U.S.', 'Weighs', 'Antitrust', 'Probe']
# Title for Row 625 = ['The', 'Wall', 'Street', 'Journal', ':', 'Blackstone', 'buy', 'warehouse', 'network', 'record', '$', '18.7', 'billion', 'deal']
# Title for Row 626 = ['FAA', 'identifies', 'potentially', 'defective', 'parts', '300', 'Boeing', '737', 'jets']
# Title for Row 627 = ['The', 'Wall', 'Street', 'Journal', ':', 'SoftBank', '’', 'bid', 'raise', 'new', '$', '100', 'billion', 'fund', 'gets', 'frosty', 'reception', 'money', 'managers']
# Title for Row 628 = ['Opinion', ':', 'Admiral', 'Faller', ':', 'Cuba', "'Protecting", "'", 'Maduro', "'Mafia", "'"]
# Title for Row 629 = ['‘', 'Godzilla', '’', 'Sequel', '’', 'Sluggish', 'Domestic', 'Debut', 'Bolstered', 'Abroad']
# Title for Row 630 = ['Opinion', ':', 'The', 'Electoral', 'College', ',', 'National', 'Weather', 'Service', ',', 'Siri']
# Title for Row 631 = ['Opinion', ':', 'Robert', 'Mueller', 'Speaks', 'What', 'Was', 'He', 'Trying', 'Say', '?']
# Title for Row 632 = ['Opinion', ':', 'Huawei', 'Becomes', 'Target', 'U.S.-China', 'Tech', 'War']
# Title for Row 633 = ['The', 'Case', 'Force', 'Venezuela', '-', 'The', 'Wall', 'Street', 'Journal']
# Title for Row 634 = ['Iran', 'Puts', 'Trump', 'Test', '-', 'The', 'Wall', 'Street', 'Journal']
# Title for Row 635 = ['In', 'Blow', 'Maduro', ',', 'Russia', 'Withdraws', 'Defense', 'Support', 'Venezuela', '...']
# Title for Row 636 = ['More', 'Americans', 'Are', 'Living', 'Solo', ',', 'Companies', 'Want', 'Their', 'Business', '-', 'The', 'Wall', 'Street', 'Journal']
# Title for Row 637 = ['A', 'Small', 'Business', 'With', 'No', 'Working', 'Website', ',', 'Felled', 'Cyberattack', '-', 'Wall', 'Street', 'Journal']
# Title for Row 638 = ['Google', '’', 'Scrutiny', 'Justice', 'Department', 'Has', 'Been', 'Building']
# Title for Row 639 = ['What', 'Siri', ',', 'Alexa', 'Google', 'Assistant', 'Can', 'Do—and', 'Annoyingly', 'Still', 'Can', '’', 'Do']
# Title for Row 640 = ['Health', 'Law', 'Improved', 'Access', 'Cancer', 'Treatment', ',', 'Studies', 'Show']
# Title for Row 641 = ['Huawei', '’', 'Main', 'Chip', 'Maker', 'Faces', 'Long-Term', 'Risks', 'From', 'U.S.', 'Ban']
# Title for Row 642 = ['Americans', 'Voters', 'Have', 'Simple', 'Health-Care', 'Message', '2020', ':', 'Just', 'Fix', 'It', '!']
# Title for Row 643 = ['Apple', 'expected', 'kill', 'iTunes']
# Title for Row 644 = ['Government', 'cybersecurity', 'scheme', 'backs', 'deep', 'web', 'AI', 'start-ups']
# Title for Row 645 = ['Most', 'doctors', 'never', 'read', 'patient', 'feedback', ',', 'report', 'finds']
# Title for Row 646 = ['Virgil', 'van', 'Dijk', 'sets', 'sights', 'Premier', 'League', 'title', 'halting', 'Spurs', 'Champions', 'League']
# Title for Row 647 = ['Hugo', 'Lloris', 'urges', 'Spurs', 'throw', 'hard', 'work', 'away', 'Champions', 'League', 'final', 'defeat']
# Title for Row 648 = ['Jordan', 'Henderson', 'dedicates', 'Champions', 'League', 'final', 'glory', 'cancer', 'survivor', 'dad']
# Title for Row 649 = ['Liverpool', 'owners', 'want', 'extend', 'Jurgen', 'Klopp', "'s", 'contract', 'enabling', 'build', 'Anfield', 'dynasty']
# Title for Row 650 = ['James', 'Milner', ':', 'Champions', 'League', 'win', 'start', 'Liverpool', 'side', 'wants', 'create', 'history']
# Title for Row 651 = ['Gentleman', 'Jack', ',', 'episode', '3', ',', 'review', ':', 'The', 'pulse', 'quickens', 'tangy', 'Georgian', 'Fleabag']
# Title for Row 652 = ['D-Day', 'veterans', 'prepare', 'set', 'sail', 'Normandy', '75', 'years', 'invasion']
# Title for Row 653 = ['Treating', 'incurable', 'prostate', 'cancer', 'earlier', 'could', 'cut', 'chance', 'early', 'death', 'third', ',', 'major', 'trial', 'finds']
# Title for Row 654 = ['Huawei', 'stops', 'production', 'smartphone', 'models', 'following', 'US', 'trade', 'sanctions']
# Title for Row 655 = ['Madrid', 'heat', 'impact', 'showed', 'players', "'", 'leggy', 'performances', 'Champions', 'League', 'final']
# Title for Row 656 = ['Wild', 'swimmers', 'revolt', 'British', 'Triathlon', 'efforts', 'prevent', 'people', 'swimming', 'cold', 'water']
# Title for Row 657 = ['Fiao', '’', 'Fa', '’', 'amausili', 'disappointed', 'fans', 'turn', 'watch', 'England', 'Women', 'face', 'Barbarians']
# Title for Row 658 = ['Tomato', ',', 'red', 'chilli', 'ricotta', 'risotto', 'recipe']
# Title for Row 659 = ['Squash', ',', 'pancetta', 'cinnamon', 'risotto', 'recipe']
# Title for Row 660 = ['Barley', 'risotto', 'red', 'wine', 'mushrooms', 'recipe']
# Title for Row 661 = ['Roasted', 'garlic', 'risotto', 'goat', '’', 'cheese', 'rosemary', 'recipe']
# Title for Row 662 = ['Scallop', 'spring', 'onion', 'risotto', 'recipe']
# Title for Row 663 = ['Gunfire', ',', 'Blasts', 'Sudan', "'s", 'Capital', 'Protest', 'Site', 'Raided']
# Title for Row 664 = ['Canadian', 'Inquiry', 'Calls', 'Killings', 'Indigenous', 'Women', 'Genocide']
# Title for Row 665 = ['Kevin', 'Hassett', ',', 'Trump', '’', 'Top', 'Economist', ',', 'Will', 'Depart']
# Title for Row 666 = ['Your', 'Monday', 'Briefing']
# Title for Row 667 = ['A', 'Top', 'North', 'Korean', 'Official', 'Reappears', ',', 'With', 'His', 'Status', 'Damaged']
# Title for Row 668 = ['N.B.A', '.', 'Finals', ':', 'Throwback', 'Night', 'Golden', 'State', 'Warriors', 'Ties', 'Series']
# Title for Row 669 = ['Witnessing', 'China', '’', '1989', 'Protests', '—', '1,000', 'Miles', 'From', 'Tiananmen', 'Square']
# Title for Row 670 = ['5', 'Cheap', '(', 'ish', ')', 'Things', 'Dip', 'Pool']
# Title for Row 671 = ['The', 'Princess', 'vs.', 'Demagogue']
# Title for Row 672 = ['简报：起底赵小兰家族；', '“', '六四', '”', '背后的权力游戏']
# Title for Row 673 = ['The', '‘', 'Fame', '’', 'High', 'School', 'Is', 'Known', 'Arts', '.', 'Should', 'Algebra', 'Matter', 'There', '?']
# Title for Row 674 = ['关于赵小兰家族与中国的密切联系，你应该知道的']
# Title for Row 675 = ['For', 'Chao', 'Family', ',', 'Deep', 'Ties', 'World', '’', '2', 'Largest', 'Economies']
# Title for Row 676 = ['Trump', 'Administration', 'Considered', 'Tariffs', 'Australia']
# Title for Row 677 = ['The', 'Fox', 'News', 'Primary', '?', 'How', 'Trump', '’', 'Favorite', 'Network', 'Became', 'Democratic', 'Power', 'Player']
# Title for Row 678 = ['Google', 'Disruptions', 'Affect', 'Gmail', ',', 'YouTube', 'Other', 'Sites']
# Title for Row 679 = ['Google', 'Disruptions', 'Affect', 'Gmail', ',', 'YouTube', 'Other', 'Sites']
# Title for Row 680 = ['Mulvaney', 'Says', 'McCain', 'Ship', 'Episode', 'Is', '‘', 'Much', 'Ado', 'About', 'Nothing', '’']
# Title for Row 681 = ['The', 'Anniversary', 'China', 'Avoids']
# Title for Row 682 = ['A', '‘', 'Bridge', '’', 'China', ',', 'Her', 'Family', '’', 'Business', ',', 'Trump', 'Cabinet']
# Title for Row 683 = ['Ecobee', '’', 'new', 'SmartThermostat', 'faster', ',', 'sleeker', ',', 'better', 'Alexa', 'speaker']
# Title for Row 684 = ['A', 'Pokémon', 'Go-style', 'Dragon', 'Quest', 'game', 'draws', 'near']
# Title for Row 685 = ['Samsung', 'announces', 'new', '13-inch', '15-inch', 'MacBook', 'Pros']
# Title for Row 686 = ['Blockbuster', 'heartfelt', 'podcast', 'series', 'George', 'Lucas', 'Steven', 'Spielberg']
# Title for Row 687 = ['Google', 'outage', 'takes', 'YouTube', ',', 'Gmail', ',', 'Snapchat', 'parts', 'US']
# Title for Row 688 = ['Samsung', 'reportedly', '‘', 'multiple', '’', 'AR', 'VR', 'products', 'way']
# Title for Row 689 = ['Minecraft', ':', 'Story', 'Mode', 'pulled', 'stores', 'June', '25th']
# Title for Row 690 = ['Watch', 'nearly', '120-year-old', 'first', 'recording', 'solar', 'eclipse']
# Title for Row 691 = ['Tesla', 'got', 'Cuphead', 'work', 'in-car', 'display']
# Title for Row 692 = ['What', 'happens', 'companies', 'defy', 'Huawei', 'ban', '?']
# Title for Row 693 = ['Amazon', 'reportedly', 'fall', 'antitrust', 'oversight', 'FTC']
# Title for Row 694 = ['Side-mounted', 'fingerprint', 'sensors', 'completely', 'underrated']
# Title for Row 695 = ['Marvel', 'adapting', 'number', 'iconic', 'comic', 'books', 'audiobooks']
# Title for Row 696 = ['Storm', 'Locusts', 'like', 'American', 'Gods', 'meets', 'Mad', 'Max', ':', 'Fury', 'Road']
# Title for Row 697 = ['Here', '’', 'look', 'life-sized', 'animals', 'AR', 'Google', 'Search']
# Title for Row 698 = ['Lyft', 'let', 'choose', 'pronouns', 'app']
# Title for Row 699 = ['Apple', 'cleared', 'Facebook', 'Instagram', 'pages', 'iTunes']
# Title for Row 700 = ['FlexTime', 'lets', 'pretend', '’', 'friends', 'Post', 'Malone', 'Kim', 'Kardashian']
# Title for Row 701 = ['11', 'new', 'trailers', 'watch', 'week']
# Title for Row 702 = ['Lyft', 'offering', 'free', 'charging', 'Portland', 'EV', 'drivers']
# Title for Row 703 = ['Elon', 'Musk', 'got', 'Cuphead', 'working', 'Tesla']
# Title for Row 704 = ['Sea', 'Thieves', 'tabletop', 'RPG', 'coming', 'fall']
# Title for Row 705 = ['Here', '’', 'crowds', 'lines', 'like', 'Star', 'Wars', 'Land', '’', 'opening', 'day']
# Title for Row 706 = ['Anti-loot', 'box', 'bill', 'poses', 'real', 'threat', 'sports', 'video', 'games']
# Title for Row 707 = ['Original', 'Doom', 'gets', 'unofficial', 'sequel', 'creator', ',', 'free']
# Title for Row 708 = ['You', '’', 'wear', 'Star', 'Wars', 'costumes', 'Galaxy', '’', 'Edge', '—', 'even', 'ones', 'sale']
# Title for Row 709 = ['Call', 'Duty', ':', 'Modern', 'Warfare', '’', 'campaign', 'feed', 'co-op', 'mode']
# Title for Row 710 = ['Star', 'Wars', 'Land', ':', 'guide', 'Galaxy', '’', 'Edge']
# Title for Row 711 = ['What', 'discovered', 'opening', 'day', 'Star', 'Wars', 'Land']
# Title for Row 712 = ['How', 'X-Men', 'First', 'Class', 'director', 'Matthew', 'Vaughn', 'hoped', 'get', 'Dark', 'Phoenix']
# Title for Row 713 = ['Spawn', ',', 'Nightwolf', ',', 'Sindel', 'confirmed', 'Mortal', 'Kombat', '11', 'DLC']
# Title for Row 714 = ['The', '20', 'best', 'comedies', 'streaming', 'Netflix', 'right']
# Title for Row 715 = ['Ali', 'Wong', ',', 'Randall', 'Park', ',', 'even', 'Keanu', 'Reeves', 'make', 'Netflix', '’', 'new', 'comedy', 'sing']
# Title for Row 716 = ['Deadwood', ':', 'The', 'Movie', 'improbable', 'gift']
# Title for Row 717 = ['Destiny', '2', 'players', 'choose', 'loot', 'upcoming', 'Season', 'Opulence']
# Title for Row 718 = ['Friday', 'Fortnite', 'back', ',', '’', 'competing', 'watch']
# Title for Row 719 = ['Classic', 'D', '&', 'D', 'RPGs', 'Baldur', '’', 'Gate', ',', 'Planescape', ':', 'Torment', 'coming', 'consoles']
# Title for Row 720 = ['We', 'asked', 'cyber', 'security', 'expert', 'rate', 'hacking', 'gameplay']
# Title for Row 721 = ['Dauntless', 'proof', 'games', 'need', 'cross-save']
# Title for Row 722 = ['Studio', 'Ghibli', 'theme', 'park', 'officially', 'coming', 'Japan', '2022']
# Title for Row 723 = ['iTunes', ':', 'Apple', 'shutting', 'music', ',', 'movie', 'libraries']
# Title for Row 724 = ['UK', 'weather', ':', 'Sun-starved', 'Poms', 'go', 'bonkers', 'heat', 'burst']
# Title for Row 725 = ['MAFS', 'stars', 'charging', 'fans', '$', '20', 'personalised', 'video', 'messages']
# Title for Row 726 = ['India', 'weather', ':', 'Temperature', 'passes', '50C', 'Celsius', 'northern', 'India']
# Title for Row 727 = ['Game', 'Thrones', ':', 'Brienne', 'Jaime', 'scene', 'final', 'season', 'misunderstood']
# Title for Row 728 = ['The', 'Voice', 'Australia', '2019', ':', 'Jack', 'Vidgen', 'makes', 'incredible', 'comeback']
# Title for Row 729 = ['Alligator', 'invades', 'home', 'leaves', 'trail', 'destruction']
# Title for Row 730 = ['Apple', 'announces', 'shut', 'iTunes', '18', 'years']
# Title for Row 731 = ['Dark', 'matter', 'discovery', ':', 'star', 'stream', '‘', 'hole', '’', 'may', 'first', 'clue']
# Title for Row 732 = ['President', 'Trump', 'labels', 'Meghan', ',', 'Duchess', 'Sussex', ',', '‘', 'nasty', '’', '.']
# Title for Row 733 = ['NASA', 'rocket', 'launch', ':', 'Arnhem', 'Land', 'chosen', 'hub']
# Title for Row 734 = ['T-cell', 'Lymphoblastic', 'Leukaemia', ':', 'Side', 'effect', 'free', 'treatment', 'breakthrough']
# Title for Row 735 = ['Weather', 'Qld', ',', 'NSW', ',', 'Vic', ':', 'Coldest', 'morning', 'Dalby', '108', 'years']
# Title for Row 736 = ['Governments', 'continue', 'cut', 'nature', 'reserves', 'protection', 'business', 'growth']
# Title for Row 737 = ['Disney', ',', 'Netflix', 'threaten', 'stop', 'movie', 'production', 'Georgia', 'abortion', 'laws']
# Title for Row 738 = ['Big', 'Little', 'Lies', 'series', 'two', ':', 'Meryl', 'Streep', 'discusses', 'character', 'Mary', 'Louise', 'Wright']
# Title for Row 739 = ['Harry', 'Potter', ':', 'Four', 'new', 'ebooks', 'published', 'wizarding', 'world']
# Title for Row 740 = ['U2', 'return', 'Australia', 'The', 'Joshua', 'Tree', 'Tour']
# Title for Row 741 = ['James', 'Packer', 'sells', 'half', 'stake', 'Crown', 'Melco']
# Title for Row 742 = ['Climate', 'change', ':', 'Photo', 'seabirds', 'starved', 'death', 'shows', 'global', 'predicament']

# %%
#Removing stop words from description

i=0
filtered_sentence = []
for i in range(y):
    words_description=word_tokenize(description[i])
    for w in words_description:
        if w not in stop_words:
            filtered_sentence.append(w)
 
    #words_description[i]=filtered_sentence        #Uncommenting this generates error
    #While trying to replace the previous description with new and stop wordsless description, it Generates Error 
    #List Assignment Index out of range
    print("Description for row ",i ,"=",filtered_sentence) 
    filtered_sentence=[]
    
    #print(words_description)   

#Single line implementation with two ifs. !!!!Currently Erroreous Code !!!!   
#filtered_sentence= w for w in words_description if not w in stop_words
# Out:
# Description for row  0 = ['Get', 'breaking', 'national', 'world', 'news', ',', 'broadcast', 'video', 'coverage', ',', 'exclusive', 'interviews', '.', 'Find', 'top', 'news', 'online', 'ABC', 'news', '.']
# Description for row  1 = ['Thirty', 'years', 'since', 'Tiananmen', 'Square', 'protests', ',', 'China', "'s", 'economy', 'catapulted', 'world', 'rankings', ',', 'yet', 'political', 'repression', 'harsher', 'ever']
# Description for row  2 = ['Chicago', 'police', 'investigating', 'video', 'posted', 'online', 'showing', 'shooting', 'death', 'woman', 'shielding', 'toddler', 'gunfire']
# Description for row  3 = ['The', 'Chicago', 'Police', 'Department', 'attributed', 'shootings', 'rash', 'gang-related', 'incidents', '.']
# Description for row  4 = ['Get', 'breaking', 'national', 'world', 'news', ',', 'broadcast', 'video', 'coverage', ',', 'exclusive', 'interviews', '.', 'Find', 'top', 'news', 'online', 'ABC', 'news', '.']
# Description for row  5 = ['A', 'senior', 'North', 'Korean', 'official', 'reported', 'purged', 'failed', 'nuclear', 'summit', 'Washington', 'shown', 'state', 'media', 'enjoying', 'concert', 'alongside', 'North', 'Korean', 'leader', 'Kim', 'Jong', 'Un']
# Description for row  6 = ['Get', 'breaking', 'national', 'world', 'news', ',', 'broadcast', 'video', 'coverage', ',', 'exclusive', 'interviews', '.', 'Find', 'top', 'news', 'online', 'ABC', 'news', '.']
# Description for row  7 = ['Boeing', 'told', 'officials', 'Federal', 'Aviation', 'Administration', '(', 'FAA', ')', 'certain', 'parts', "'s", 'grounded', '737', 'Max', 'passenger', 'plane', 'may', 'improperly', 'manufactured', '.']
# Description for row  8 = ['Human', 'rights', 'lawyers', 'accusing', 'European', 'Union', 'committing', 'crimes', 'humanity', 'treatment', 'migrants', 'hope', 'cross', 'Mediterranean', 'Libya']
# Description for row  9 = ['Get', 'breaking', 'national', 'world', 'news', ',', 'broadcast', 'video', 'coverage', ',', 'exclusive', 'interviews', '.', 'Find', 'top', 'news', 'online', 'ABC', 'news', '.']
# Description for row  10 = ['Kayla', 'Oblisk', 'said', '2-year-old', 'son', ',', 'Jackson', ',', 'came', 'case', 'Rocky', 'Mountain', 'spotted', 'fever', '.']
# Description for row  11 = ['Authorities', 'say', 'nobody', 'hurt', 'explosion', 'chemical', 'plant', 'shook', 'buildings', 'miles', 'around', 'San', 'Francisco', 'Bay', 'Area']
# Description for row  12 = ['Boeing', 'telling', 'airlines', 'flying', '737', 'replace', 'part', 'planes', "'", 'wings', ',', 'move', 'could', 'affect', '100', 'planes']
# Description for row  13 = ['Retired', 'Miami', 'Heat', 'star', 'Dwyane', 'Wade', 'surprised', 'graduates', 'Marjory', 'Stoneman', 'Douglas', 'High', 'School', 'Parkland', ',', 'Florida', '.']
# Description for row  14 = ['Get', 'breaking', 'national', 'world', 'news', ',', 'broadcast', 'video', 'coverage', ',', 'exclusive', 'interviews', '.', 'Find', 'top', 'news', 'online', 'ABC', 'news', '.']
# Description for row  15 = ['Get', 'breaking', 'national', 'world', 'news', ',', 'broadcast', 'video', 'coverage', ',', 'exclusive', 'interviews', '.', 'Find', 'top', 'news', 'online', 'ABC', 'news', '.']
# Description for row  16 = ['Google', 'saying', 'users', 'YouTube', 'services', 'seeing', 'errors', 'slow', 'performance', 'due', 'high', 'levels', 'network', 'congestions', 'eastern', 'United', 'States', '.']
# Description for row  17 = ['The', 'close', 'call', 'happened', 'Enchantment', 'Park', 'central', 'Washington', 'dusk', '.']
# Description for row  18 = ['Get', 'breaking', 'national', 'world', 'news', ',', 'broadcast', 'video', 'coverage', ',', 'exclusive', 'interviews', '.', 'Find', 'top', 'news', 'online', 'ABC', 'news', '.']
# Description for row  19 = ['Syrian', 'opposition', 'activists', 'reporting', 'car', 'bomb', 'northern', 'town', 'held', 'Turkey-backed', 'fighters', 'killed', 'least', '13', ',', 'wounded', 'dozens', 'people']
# Description for row  20 = ['Israeli', 'police', 'Palestinian', 'worshippers', 'clashed', 'Al', 'Aqsa', 'mosque', ',', 'holy', 'site', 'known', 'Jews', 'Temple', 'Mount', '.']
# Description for row  21 = ['Kim', 'Yong-chol', 'reported', 'labour', 'camp', 'Sunday', 'enjoyed', 'show', 'alongside', 'Kim', 'Jong-un', '.']
# Description for row  22 = ['Police', 'speaking', '13-year-old', 'passenger', 'flight', 'allegedly', 'behind', 'hoax', '.']
# Description for row  23 = ['The', 'latest', 'five', 'minute', 'news', 'bulletin', 'BBC', 'World', 'Service', '.']
# Description for row  24 = ['The', '``', 'inclusion', 'workshops', "''", 'come', 'singer', 'SZA', 'said', 'racially', 'profiled', 'Sephora', 'store', '.']
# Description for row  25 = ['They', 'faced', 'criticism', 'discouragement', ',', 'determined', 'get', 'behind', 'wheel', '.']
# Description for row  26 = ['The', 'latest', 'five', 'minute', 'news', 'bulletin', 'BBC', 'World', 'Service', '.']
# Description for row  27 = ['ITV2', 'made', 'alterations', 'successful', 'show', 'year', '.']
# Description for row  28 = ['The', 'latest', 'five', 'minute', 'news', 'bulletin', 'BBC', 'World', 'Service', '.']
# Description for row  29 = ['Theresa', 'May', 'raise', 'issue', 'climate', 'change', 'Donald', 'Trump', 'upcoming', 'visit', 'UK', '.']
# Description for row  30 = ['Entrepreneur', 'Gerald', 'Manu', 'explains', 'hardships', 'starting', 'fashion', 'brand', 'school', '.']
# Description for row  31 = ['A', 'BBC', 'investigation', 'uncovered', 'evidence', 'tax', 'dodging', 'wealthy', 'businessman', 'Frank', 'Timis', '.']
# Description for row  32 = ['The', 'British', 'retail', 'tycoon', 'makes', 'final', 'effort', 'stave', 'administration', 'breakup', 'group', '.']
# Description for row  33 = ['The', 'latest', 'five', 'minute', 'news', 'bulletin', 'BBC', 'World', 'Service', '.']
# Description for row  34 = ['What', '``', 'small', 'city', 'great', 'international', 'flavour', "''", 'want', 'new', 'MP', '?']
# Description for row  35 = ['How', 'Houzz', 'went', 'side', 'project', 'global', 'phenomenon', 'less', 'decade', '.']
# Description for row  36 = ['Pope', 'Francis', 'addressed', '‘', 'discrimination', ',', 'segregation', ',', 'mistreatment', '’', 'Roma', 'people', 'suffered', 'hands', 'church', '.', 'Also', ':', 'The', 'US', 'says', 'make', 'assessments', 'ensure', 'Iran', 'never', 'able', 'build', 'nuclear', 'weapon', ',', 'man', 'set', 'rele…']
# Description for row  37 = ['President', 'Trump', 'crosses', 'pond', 'top', 'players', 'women', "'s", 'football', 'showcase', 'skills', '.']
# Description for row  38 = ['It', 'broken', ',', 'rebuilt', 'wrong', 'way', 'cruelly', 'called', '``', 'muffin', 'top', "''", '-', 'sculpture', 'stands', 'proud', '.']
# Description for row  39 = ['The', 'papers', 'report', 'tensions', 'US', 'ahead', 'president', "'s", 'arrival', 'Liverpool', "'s", 'parade', '.']
# Description for row  40 = ['After', 'evening', 'series', 'Game', '2', 'win', ',', 'Golden', 'State', 'Warriors', '5.5-point', 'favorites', 'Toronto', 'Raptors', 'Game', '3', ':', 'They', 'also', 'heavy', 'favorites', '...']
# Description for row  41 = ['Golden', 'State', 'Warriors', 'shooting', 'guard', 'Klay', 'Thompson', ',', 'left', 'Game', '2', 'NBA', 'Finals', 'versus', 'Toronto', 'Raptors', 'left', 'hamstring', 'tightness', 'return', ',', 'told', 'Rachel', '...']
# Description for row  42 = ['A', 'wide-open', 'Andre', 'Iguodala', 'three-pointer', 'capped', 'Golden', 'State', 'Warriors', "'", '109-104', 'win', 'Toronto', 'Raptors', 'Game', '2', 'NBA', 'Finals', 'Sunday', ':', 'After', 'game', ',', '...']
# Description for row  43 = ['Golden', 'State', 'Warriors', 'guard/forward', 'Andre', 'Iguodala', 'knocked', 'cold-blooded', 'three-pointer', 'seal', 'team', "'s", '109-104', 'win', 'Toronto', 'Raptors', 'Game', '2', 'NBA', 'Finals', 'Sunday', '...']
# Description for row  44 = ['Golden', 'State', 'Warriors', 'star', 'Klay', 'Thompson', 'left', 'Game', '2', 'NBA', 'Finals', 'Toronto', 'Raptors', 'Sunday', 'left', 'hamstring', 'tightness', 'return', ',', 'per', 'team', 'report', '...']
# Description for row  45 = ['The', 'Golden', 'State', 'Warriors', 'back', 'control', 'NBA', 'Finals', 'evening', 'series', '1-1', '.', 'Klay', 'Thompson', 'scored', '25', 'points', 'lead', 'Golden', 'State', '109-104', 'win', 'Toronto', 'Raptors', 'Game', '2', 'Sunday', '...']
# Description for row  46 = ['Golden', 'State', 'Warriors', 'forward/center', 'Kevon', 'Looney', 'miss', 'remainder', 'Game', '2', 'NBA', 'Finals', 'sprained', 'collarbone', ',', 'per', 'Shams', 'Charania', 'Stadium', 'The', 'Athletic', '...']
# Description for row  47 = ['The', 'Michigan', 'Wolverines', 'without', 'Chris', 'Evans', '2019', 'season', ',', 'running', 'back', 'suspended', 'academic', 'issues', ',', 'head', 'coach', 'Jim', 'Harbaugh', 'confirmed', 'Angelique', 'S', '...']
# Description for row  48 = ['Drake', 'showed', 'Scotiabank', 'Arena', 'Game', '2', 'NBA', 'Finals', 'hoodie', 'featuring', 'Kevin', 'McCallister', ',', 'iconic', 'Home', 'Alone', 'protagonist', 'defended', 'family', "'s", 'house', 'burglars', 'Christmas', 'Eve', '...']
# Description for row  49 = ['Jahvon', 'Quinerly', 'announced', 'decision', 'transfer', 'Villanova', 'Alabama', ',', 'according', 'Evan', 'Daniels', '247Sports', '...']
# Description for row  50 = ['Drake', 'become', 'synonymous', 'everything', 'Toronto', 'Raptors', 'franchise', "'s", 'first', 'run', 'NBA', 'Finals', ',', '2011', 'verse', '``', 'Always', 'presidential', 'tonight', "'s", 'blue', 'moon', "''", 'never', 'relevant', 'ahead', 'Sunday', 'night', "'s", 'Game', '2', '...']
# Description for row  51 = ['The', 'demand', 'seats', '2019', 'NBA', 'Finals', 'led', 'new', 'record', 'ticket', 'cost', '.', 'According', 'Darren', 'Rovell', 'Action', 'Network', ',', 'person', 'spent', '$', '101,015', 'two', 'courtside', '...']
# Description for row  52 = ['Baseball', 'games', 'delayed', 'rain', ',', 'snow', ',', 'earthquake', ',', 'fans', 'running', 'field', ',', 'power', 'outages', ',', 'leaky', 'fountains', ',', 'sprinklers', ',', 'stray', 'cat', 'Michael', 'Jordan', 'landing', 'middle', 'outfield', 'alien', 'spaceship', '...']
# Description for row  53 = ['Golden', 'State', 'Warriors', 'head', 'coach', 'Steve', 'Kerr', 'advocated', 'stricter', 'gun', 'control', 'laws', 'wake', 'latest', 'American', 'mass', 'shooting', '...']
# Description for row  54 = ['Jan', 'Vertonghen', 'hopes', 'Tottenham', 'Hotspur', "'s", 'key', 'players', 'wo', "n't", 'leave', 'wake', 'club', "'s", '2-0', 'defeat', 'Liverpool', '2019', 'UEFA', 'Champions', 'League', 'final', 'Saturday', '...']
# Description for row  55 = ['Illinois', 'likely', 'become', 'latest', 'state', 'legalize', 'sports', 'gambling', '.', 'According', 'David', 'Purdum', 'ESPN', ',', 'Illinois', 'legislature', 'passed', 'broad', 'funding', 'bill', 'Sunday', ',', 'allow', 'betting', 'online', 'well', 'casinos', 'racetracks', '...']
# Description for row  56 = ['Jeongeun', 'Lee6', '2019', 'U.S.', 'Women', "'s", 'Open', 'champion', ',', 'becoming', 'first', 'woman', 'take', 'home', '$', '1', 'million', 'tournament', "'s", 'history', '...']
# Description for row  57 = ['Patrick', 'Cantlay', 'shot', 'eight-under', '64', 'final', 'round', '19-under', 'overall', 'win', 'Memorial', 'Tournament', 'Muirfield', 'Village', 'Golf', 'Club', 'Dublin', ',', 'Ohio', ',', 'Sunday', '...']
# Description for row  58 = ['Former', 'WWE', 'champion', 'Batista', "'s", 'profile', 'Hollywood', 'continues', 'grow', 'receives', 'commercial', 'critical', 'success', ',', 'transition', 'acting', "n't", 'without', 'hardship', '...']
# Description for row  59 = ['Los', 'Angeles', 'Dodgers', 'pitcher', 'Tony', 'Cingrani', 'likely', 'miss', 'rest', '2019', 'season', 'undergoing', 'arthroscopic', 'surgery', 'left', 'shoulder', ',', 'according', 'J.P.', 'Hoornstra', 'Los', 'Angeles', 'Daily', 'News', '...']
# Description for row  60 = ['America', "'s", 'business', 'leaders', 'growing', 'worried', 'United', 'States', 'enter', 'recession', 'end', '2020', '.', 'Their', 'primary', 'fear', ':', 'protectionist', 'trade', 'policy', '.']
# Description for row  61 = ['Three', 'congressman', 'currently', 'sit', 'bottom', 'polls', 'sought', 'start', 'climbs', 'crowded', 'Democratic', 'presidential', 'field', 'trio', 'CNN', 'town', 'halls', 'Sunday', 'night', '.']
# Description for row  62 = ['With', 'affordable', 'flights', 'high-speed', 'rails', ',', "'s", 'easier', 'ever', 'visit', 'Asia', '.', 'From', 'India', 'Indonesia', ',', 'find', 'best', 'places', 'visit', 'next', 'holiday', '.']
# Description for row  63 = ['During', 'CNN', 'Town', 'Hall', ',', 'Rep.', 'Eric', 'Swalwell', '(', 'D-CA', ')', 'said', 'thinks', 'time', 'come', 'start', 'impeachment', 'proceedings', 'Attorney', 'General', 'William', 'Barr', 'Treasury', 'Secretary', 'Steven', 'Mnuchin', '.']
# Description for row  64 = ['As', 'sun', 'rose', 'morning', 'June', '4', ',', '1989', ',', 'Chinese', 'people', 'woke', 'country', 'changed', 'overnight', '.']
# Description for row  65 = ['Thirty', 'years', 'ago', ',', 'heart', 'Chinese', 'capital', 'Beijing', ',', 'Dong', 'Shengkun', 'threw', 'two', 'flaming', ',', 'gas-soaked', 'rags', 'military', 'truck', 'night', 'bloody', 'violence', 'city', '.', 'It', 'move', 'would', 'ruin', 'life', '.']
# Description for row  66 = ['The', 'Washington', 'State', 'Department', 'Fish', 'Wildlife', 'said', 'cougar', 'displaying', '``', 'abnormal', 'behavior', '.', "''"]
# Description for row  67 = ['Philippine', 'President', 'Rodrigo', 'Duterte', 'told', 'crowd', '``', 'used', 'gay', "''", '``', 'cured', "''", '.']
# Description for row  68 = ['CNN', "'s", 'Brian', 'Stelter', 'explains', 'importance', 'special', 'counsel', 'Robert', 'Mueller', 'seen', 'heard', 'television', 'American', 'people', '.']
# Description for row  69 = ['Secretary', 'State', 'Mike', 'Pompeo', 'attempted', 'tamper', 'expectations', 'Trump', 'administration', "'s", 'Middle', 'East', 'peace', 'plan', 'closed-door', 'meeting', 'Jewish', 'leaders', ',', 'The', 'Washington', 'Post', 'reported', 'Sunday', '.']
# Description for row  70 = ['Secretary', 'State', 'Mike', 'Pompeo', 'attempted', 'tamper', 'expectations', 'Trump', 'administration', "'s", 'Middle', 'East', 'peace', 'plan', 'closed-door', 'meeting', 'Jewish', 'leaders', ',', 'The', 'Washington', 'Post', 'reported', 'Sunday', '.']
# Description for row  71 = ['It', 'looks', 'like', 'Drake', 'curse', 'struck', '.']
# Description for row  72 = ['Dow', 'futures', 'nearly', '200', 'points', 'lower', 'Sunday', 'evening', 'Wall', 'Street', 'braced', 'fallout', 'worsening', 'global', 'trade', 'tensions', '.']
# Description for row  73 = ['A', 'former', 'member', 'Nxivm', 'testifies', 'group', 'members', 'kept', 'forced', 'isolation', 'two', 'years', 'without', 'seeing', 'family', '.', 'The', 'woman', ',', 'identified', 'prosecutors', '``', 'Daniela', ',', "''", 'also', 'testified', 'group', "'s", 'founder', ',', 'Keith', 'Raniere', ',', 'trial', 'Brooklyn', ',', 'New', '…']
# Description for row  74 = ['Massachusetts', 'Rep.', 'Seth', 'Moulton', 'said', 'Sunday', 'Democrat', 'Stacey', 'Abrams', 'governor', 'Georgia', ',', 'said', 'would', 'US', '``', "n't", 'racist', '.', "''"]
# Description for row  75 = ['Seth', 'Moulton', 'writes', 'experience', 'PTS', 'serving', 'Marines', ',', 'felt', 'make', 'part', 'life', 'public', ',', 'plans', 'president', 'help', 'veterans', 'civilians', 'mental', 'health', 'challenges', '.']
# Description for row  76 = ['El', 'Boeing', '737', 'fue', 'puesto', 'en', 'tierra', 'en', 'todo', 'el', 'mundo', 'después', 'de', 'un', 'accidente', 'fatal', 'en', 'un', 'avión', 'de', 'Ethiopian', 'Airlines', 'en', 'marzo', '.']
# Description for row  77 = ['When', 'animal', 'rights', 'protester', 'leapt', 'stage', 'Saturday', 'confront', 'Kamala', 'Harris', ',', 'one', 'people', 'rushed', 'onstage', 'grab', 'husband', 'Doug', 'Emhoff—a', 'man', 'unknown', 'voters', ',', 'constant', 'presence', 'side', 'campaign', 'trail', '.']
# Description for row  78 = ['The', 'United', 'States', 'tightening', 'screws', 'several', 'allies', 'escalating', 'global', 'trade', 'battle', '.', 'India', 'latest', 'target', '.']
# Description for row  79 = ['``', 'I', "'m", 'proud', 'say', 'words', "'MSD", 'Strong', ',', "'", "''", 'Wade', 'said', '.']
# Description for row  80 = ['The', 'Golden', 'State', 'Warriors', 'opened', 'third', 'quarter', '18-0', 'run', 'held', 'evened', 'best-of-seven', 'NBA', 'Finals', 'series', 'one', 'game', 'apiece', ',', '109-104', 'win', 'Toronto', 'Raptors', '.']
# Description for row  81 = ['Preparing', 'prom', 'much', 'picking', 'dress', '.']
# Description for row  82 = ['When', 'Delray', 'responds', 'call', ',', '’', 'paramedics', 'ones', 'get', 'helping', 'hand', '—', 'helping', 'paw', ',', 'actually', '.']
# Description for row  83 = ['The', 'garbage', 'fiasco', 'Phillipines', 'Canada', 'shows', 'putting', 'waste', 'right', 'bin', "n't", 'guarantee', 'stay', 'landfill', '.', 'Some', 'people', 'say', "'re", 'taking', 'matters', 'hands', 'avoiding', 'plastic', 'packaging', 'altogether', '.']
# Description for row  84 = ['An', 'officer', 'jumped', 'way', 'speeding', 'vehicle', ',', 'shot', 'fired', ',', 'vehicles', 'rammed', 'failed', 'takedown', 'Dayton', 'McAlpine', '.']
# Description for row  85 = ['Last', 'week', ',', 'Calia', 'Pacle', ',', 'battered', 'competition', '(', 'pun', 'intended', ')', 'Skills', 'Canada', 'baking', 'competition', 'Halifax', ',', 'took', 'home', 'gold', '.']
# Description for row  86 = ['Alberta', 'wildlife', 'photographer', 'Abdulla', 'Moussa', 'captured', 'rare', 'photo', 'last', 'week', 'white', ',', 'black', 'bear', 'cub', 'Kananaskis', '.']
# Description for row  87 = ['Flames', 'smoke', 'could', 'seen', 'billowing', '15th', 'floor', 'balcony', '.']
# Description for row  88 = ['More', '8,000', 'attendees', 'arrived', 'University', 'British', 'Columbia', 'hosts', 'Congress', 'Humanities', 'Social', 'Sciences', '.']
# Description for row  89 = ['Junichi', 'Mitsubori', 'culinary', 'rockstar', 'Japan', ',', 'famous', 'intricate', 'dessert', 'sculptures', 'known', '``', 'wagashi', '.', "''"]
# Description for row  90 = ['Two', 'families', 'demanding', 'answers', 'major', 'airlines', 'elderly', 'parents', 'abandoned', 'airport', 'hours', '—', 'without', 'help', 'access', 'food', ',', 'water', 'washrooms', '.']
# Description for row  91 = ['A', 'severe', 'thunderstorm', 'north', 'Montreal', 'could', 'possibly', 'produce', 'tornado', 'evening', ',', 'Environment', 'Canada', 'warns', '.']
# Description for row  92 = ['A', 'Vancouver', 'architecture', 'firm', 'pushing', 'concept', '``', 'gentle', 'densification', "''", 'unique', 'project', 'West', 'End', 'puts', 'six', 'units', 'dedicated', 'rental', 'housing', 'single', 'family', 'lot', '.']
# Description for row  93 = ['RCMP', 'Major', 'Crimes', 'unit', 'investigating', 'man', '’', 'body', 'found', 'scene', 'fire', 'outside', 'Slave', 'Lake', '.']
# Description for row  94 = ['Jeongeun', 'Lee6', 'No', '.', '1', 'U.S.', 'Women', "'s", 'Open', '.', 'The', '23-year-old', 'South', 'Korean', 'shot', '1-under', '70', 'Sunday', ',', 'enduring', 'shaky', 'moments', 'opening', 'three-stroke', 'lead', 'three', 'play', 'hold', 'third-round', 'co-leader', 'Celine', 'Boutier', '.']
# Description for row  95 = ['Antonio', 'Senzatela', 'pitched', 'six', 'effective', 'innings', ',', 'Nolan', 'Arenado', 'Chris', 'Iannetta', 'homered', 'Colorado', 'Rockies', 'beat', 'Toronto', 'Blue', 'Jays', '5-1', 'Sunday', 'eighth', 'straight', 'win', '.']
# Description for row  96 = ['It', '’', 'true', '.', 'Canada', 'trophy', '.', 'Hold', 'applause', '.', 'Canada', 'leave', 'France', 'empty', 'handed', '.', 'For', 'first', 'time', 'season', ',', 'Canadians', 'bringing', 'home', 'Sevens', 'silverware', '.', 'It', 'real', 'trophy', '—', 'THE', 'trophy', '.']
# Description for row  97 = ['Residents', 'Ottawa', "'s", 'east', 'end', 'neighbourhood', 'Orléans', 'assessing', 'damage', 'major', 'storm', 'Sunday', 'evening', 'saw', 'tornado', 'rip', 'region', '.']
# Description for row  98 = ['Environment', 'Canada', 'lifted', 'tornado', 'warning', 'Gatineau', ',', 'Que.', ',', 'remains', 'effect', 'parts', 'western', 'Quebec', 'eastern', 'Ontario', '.', 'A', 'tornado', 'spotted', 'near', 'Gatineau', 'airport', '5:55', 'p.m.', ',', 'weather', 'agency', 'said', '.']
# Description for row  99 = ['Environment', 'Canada', 'issued', 'tornado', 'warning', 'Gatineau', 'parts', 'Outaouais', ',', 'well', 'Prescott-Russell', ',', 'Ont', '.']
# Description for row  100 = ['A', 'high-level', 'colonel', 'Chinese', 'military', 'admits', "'s", 'possibility', '``', 'miscalculation', "''", 'South', 'China', 'Sea', ',', 'defended', 'China', "'s", '``', 'need', "''", 'protect', 'Beijing', 'deems', 'territory', '.']
# Description for row  101 = ['The', 'U.S.', 'Transportation', 'Department', 'expected', 'provide', 'tentative', 'approval', 'bid', 'American', 'Airlines', 'Qantas', 'Airways', 'operate', 'joint', 'venture', ',', 'two', 'people', 'briefed', 'matter', 'said', 'Sunday', '.']
# Description for row  102 = ['LVMH', "'s", 'Sephora', 'beauty', 'chain', 'said', 'close', 'U.S.', 'stores', ',', 'distribution', 'centers', 'corporate', 'offices', 'Wednesday', 'conduct', 'diversity', 'training', 'employees', ',', 'move', 'follows', 'racial', 'incident', 'involving', 'Grammy-nominated', 'singer', '.']
# Description for row  103 = ['U.S.', 'President', 'Donald', 'Trump', 'said', 'Sunday', 'White', 'House', 'Council', 'Economic', 'Advisers', 'Chairman', 'Kevin', 'Hassett', '``', 'shortly', "''", 'leave', 'post', '.']
# Description for row  104 = ['The', 'Caixin/Markit', 'factory', 'Purchasing', 'Managers', "'", 'Index', 'May', '50.2', '.', 'Analysts', 'polled', 'Reuters', 'expected', 'manufacturing', 'indicator', 'come', '50', '.']
# Description for row  105 = ['Oil', 'prices', 'declined', '1', '%', 'Monday', 'extend', 'losses', '3', '%', 'Friday', ',', 'crude', 'markets', 'racked', 'biggest', 'monthly', 'losses', 'six', 'months', 'amid', 'stalling', 'demand', 'trade', 'wars', 'fanned', 'fears', 'slowdown', 'global', 'economy', '.']
# Description for row  106 = ['Microsoft', "'s", 'battle', 'Justice', 'Department', 'dragged', 'almost', 'decade', '.', 'If', 'DOJ', 'investigates', 'Google', ',', 'expect', 'things', 'move', 'quickly', ',', 'according', 'two', 'antitrust', 'lawyers', '.']
# Description for row  107 = ['North', 'Korean', 'senior', 'official', 'former', 'top', 'nuclear', 'envoy', 'Kim', 'Yong', 'Chol', 'reportedly', 'accompanied', 'leader', 'Kim', 'Jong', 'Un', 'Sunday', 'art', 'performance', 'signaling', 'former', 'spymaster', 'alive', 'remains', 'force', 'North', 'Korea', "'s", 'power', 'structure', '.']
# Description for row  108 = ['Stocks', 'Asia', 'poised', 'decline', 'first', 'trading', 'day', 'June', 'amid', 'increasing', 'global', 'trade', 'concerns', '.']
# Description for row  109 = ['Federated', 'Investors', "'", 'Phil', 'Orlando', 'takes', 'exposure', 'stocks', 'due', 'growing', 'uncertainty', 'surrounding', 'trade', '.']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-fe89d96c539c> in <module>()
#       4 filtered_sentence = []
#       5 for i in range(y):
# ----> 6     words_description=word_tokenize(description[i])
#       7     for w in words_description:
#       8         if w not in stop_words:
#
# E:\Anaconda\lib\site-packages\nltk\tokenize\__init__.py in word_tokenize(text, language, preserve_line)
#     141     :type preserve_line: bool
#     142     """
# --> 143     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     144     return [
#     145         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#
# E:\Anaconda\lib\site-packages\nltk\tokenize\__init__.py in sent_tokenize(text, language)
#     103     """
#     104     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
# --> 105     return tokenizer.tokenize(text)
#     106
#     107
#
# E:\Anaconda\lib\site-packages\nltk\tokenize\punkt.py in tokenize(self, text, realign_boundaries)
#    1267         Given a text, returns a list of the sentences in that text.
#    1268         """
# -> 1269         return list(self.sentences_from_text(text, realign_boundaries))
#    1270
#    1271     def debug_decisions(self, text):
#
# E:\Anaconda\lib\site-packages\nltk\tokenize\punkt.py in sentences_from_text(self, text, realign_boundaries)
#    1321         follows the period.
#    1322         """
# -> 1323         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1324
#    1325     def _slices_from_text(self, text):
#
# E:\Anaconda\lib\site-packages\nltk\tokenize\punkt.py in <listcomp>(.0)
#    1321         follows the period.
#    1322         """
# -> 1323         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1324
#    1325     def _slices_from_text(self, text):
#
# E:\Anaconda\lib\site-packages\nltk\tokenize\punkt.py in span_tokenize(self, text, realign_boundaries)
#    1311         if realign_boundaries:
#    1312             slices = self._realign_boundaries(text, slices)
# -> 1313         for sl in slices:
#    1314             yield (sl.start, sl.stop)
#    1315
#
# E:\Anaconda\lib\site-packages\nltk\tokenize\punkt.py in _realign_boundaries(self, text, slices)
#    1352         """
#    1353         realign = 0
# -> 1354         for sl1, sl2 in _pair_iter(slices):
#    1355             sl1 = slice(sl1.start + realign, sl1.stop)
#    1356             if not sl2:
#
# E:\Anaconda\lib\site-packages\nltk\tokenize\punkt.py in _pair_iter(it)
#     315     """
#     316     it = iter(it)
# --> 317     prev = next(it)
#     318     for el in it:
#     319         yield (prev, el)
#
# E:\Anaconda\lib\site-packages\nltk\tokenize\punkt.py in _slices_from_text(self, text)
#    1325     def _slices_from_text(self, text):
#    1326         last_break = 0
# -> 1327         for match in self._lang_vars.period_context_re().finditer(text):
#    1328             context = match.group() + match.group('after_tok')
#    1329             if self.text_contains_sentbreak(context):
#
# TypeError: expected string or bytes-like object
